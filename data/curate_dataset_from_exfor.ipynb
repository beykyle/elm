# %% [markdown]
# # Curating a data set for elastic $(p,p)$ and $(n,n)$ scattering and $(p,n)$ to the isobaric analog state for multiple isotopes
#
#  We will make use of the class `TargetData` class in `exfor_tools.curate`.

# %%
from exfor_tools import Reaction, curate, quantities
from periodictable import elements
# Out:
# Using database version X4-2024-12-31 located in: /home/kyle/db/exfor/unpack_exfor-2024/X4-2024-12-31

# %% [markdown]
# We will use the 2024 evaluation, avilable here: https://nds.iaea.org/nrdc/exfor-master/list.html
#
# If you have an older version, instructions for updating the database for your `exfor_tools` install are available here: https://github.com/beykyle/exfor_tools?tab=readme-ov-file#updating-the-exfor-data-base

# %%
import numpy as np
from IPython.display import Latex, Math, display

# %%
print(quantities)
# Out:
# ['dXS/dA', 'dXS/dRuth', 'Ay']

# %%
Ca48 = (48, 20)
Ca44 = (44, 20)
Ca42 = (42, 20)
Ca40 = (40, 20)

Ni64 = (64, 28)
Sr86 = (86, 38)
Sr88 = (88, 38)
Mo92 = (92, 42)
Mo94 = (94, 42)

Ba138 = (138, 56)
Ce140 = (140, 58)

Pb206 = (206, 82)
Pb208 = (208, 82)

Sm144 = (144, 62)
Sm148 = (148, 62)

Sn116 = (116, 50)
Sn118 = (118, 50)
Sn120 = (120, 50)
Sn122 = (122, 50)
Sn124 = (124, 50)

Zr90 = (90, 40)
Zr92 = (92, 40)
Zr94 = (94, 40)
Zr96 = (96, 40)

neutron = (1, 0)
proton = (1, 1)

# %%
projectiles = [neutron, proton]

# %%
beta2_by_target = dict(
    [
        (Ca48, 0.1074),
        (Ca44, 0.251),
        (Ca42, 0.2454),
        (Ca40, 0.11712),
        (Ni64, 0.1583),
        (Sr86, 0.1444),
        (Sr88, 0.1153),
        (Zr90, 0.091911),
        (Zr92, 0.1014),
        (Zr94, 0.08810),
        (Zr96, 0.0604),
        (Mo92, 0.1093),
        (Mo94, 0.1511),
        (Sn116, 0.111715),
        (Sn118, 0.110122),
        (Sn120, 0.107110),
        (Sn122, 0.102811),
        (Sn124, 0.0095216),
        (Ba138, 0.0938),
        (Ce140, 0.102),
        (Sm144, 0.088),
        (Sm148, 0.142),
        (Pb206, 0.03235),
        (Pb208, 0.056314),
    ]
)

# %%
max_beta2 = 0.16
targets = list(
    [target for target, beta2 in beta2_by_target.items() if beta2 < max_beta2]
)
for target in targets:
    display(Math(f"^{{{target[0]}}} \\rm{{{elements[target[1]]}}}"))
# Out:
# $\displaystyle ^{48} \rm{Ca}$
# $\displaystyle ^{40} \rm{Ca}$
# $\displaystyle ^{64} \rm{Ni}$
# $\displaystyle ^{86} \rm{Sr}$
# $\displaystyle ^{88} \rm{Sr}$
# $\displaystyle ^{90} \rm{Zr}$
# $\displaystyle ^{92} \rm{Zr}$
# $\displaystyle ^{94} \rm{Zr}$
# $\displaystyle ^{96} \rm{Zr}$
# $\displaystyle ^{92} \rm{Mo}$
# $\displaystyle ^{94} \rm{Mo}$
# $\displaystyle ^{116} \rm{Sn}$
# $\displaystyle ^{118} \rm{Sn}$
# $\displaystyle ^{120} \rm{Sn}$
# $\displaystyle ^{122} \rm{Sn}$
# $\displaystyle ^{124} \rm{Sn}$
# $\displaystyle ^{138} \rm{Ba}$
# $\displaystyle ^{140} \rm{Ce}$
# $\displaystyle ^{144} \rm{Sm}$
# $\displaystyle ^{148} \rm{Sm}$
# $\displaystyle ^{206} \rm{Pb}$
# $\displaystyle ^{208} \rm{Pb}$

# %%
energy_range = [10, 200]
min_num_points = 5

# if normalization uncertainty isn't reported assign it to be 5%
default_systematic_normalization_err = 0.05

settings = {
    "Einc_range": energy_range,
    "filter_kwargs": {"min_num_pts": min_num_points},
}

entries_to_ignore_pp_absolute = [
    "E0120",
    "C0078",  # redundant, huge uncertainties
    "E0795",  # duplicate, no uncertainties
    "O0032",  # duplicate to E0166 and E0249
    "E0249",  # duplicate to E0166 and O0032
    "O0253",  # duplicate to Ruth O0253
    "C3000",  # no uncertainties
    "E0904",  # no uncertainties
]
entries_to_ignore_pp_Ruth = [
    "O0490",
    "E0120",  # no uncertainties
    "O0432",  # no uncertainties
    "C3001",  # no uncertainties
    "E1846",  # no uncertainties
    "C1397",  # no uncertainties
]

entries_to_ignore_nn = [
    "14317",  # duplicate
]

# %% [markdown]
# ## EXFOR querying and parsing

# %% [markdown]
# ## Parsing $(n,n)$ data

# %%
nn_data = dict(
    [
        (
            target,
            curate.MulltiQuantityReactionData(
                Reaction(target=target, projectile=neutron),
                quantities=["dXS/dA"],
                settings=settings,
                vocal=True,
            ),
        )
        for target in targets
    ]
)
# Out:
# ========================================================
# Now parsing dXS/dA for $^{48}$Ca$(n,n)$
#
# ========================================================
# Found subentry 14303004 with the following columns:
# ['EN', 'EN-ERR', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 14303005 with the following columns:
# ['EN', 'EN-ERR', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{40}$Ca$(n,n)$
#
# ========================================================
# Found subentry 12785002 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 12996002 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA', 'DATA-ERR']
# Found subentry 13946003 with the following columns:
# ['EN', 'EN-ERR', 'ANG-CM', 'DATA-CM', 'ERR-S', 'ERR-SYS']
# Found subentry 14303002 with the following columns:
# ['EN', 'EN-ERR', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 14303003 with the following columns:
# ['EN', 'EN-ERR', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 4 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{64}$Ni$(n,n)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{86}$Sr$(n,n)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{88}$Sr$(n,n)$
#
# ========================================================
# Found subentry 10729004 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'ERR-S']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{90}$Zr$(n,n)$
#
# ========================================================
# Found subentry 10729002 with the following columns:
# ['EN', 'ANG-CM', 'EN-RSL', 'DATA-CM', 'ERR-S']
# Found subentry 13160003 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 13160004 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{92}$Zr$(n,n)$
#
# ========================================================
# Found subentry 13160013 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 13160014 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{94}$Zr$(n,n)$
#
# ========================================================
# Found subentry 13160018 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 13160019 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{96}$Zr$(n,n)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{92}$Mo$(n,n)$
#
# ========================================================
# Found subentry 10633012 with the following columns:
# ['EN', 'DATA-ERR2', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ANG-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR1']
# Failed to parse subentry 10633012:
# 	Ambiguous statistical error labels:
# DATA-ERR2, MONIT-ERR, DATA-ERR1
# Found subentry 10729007 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-S']
# Found subentry 10867002 with the following columns:
# ['ANG-ERR', 'ERR-1', 'EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Failed to parse subentry 10867002:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-T
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 2 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{94}$Mo$(n,n)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{116}$Sn$(n,n)$
#
# ========================================================
# Found subentry 10817006 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 13158005 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{118}$Sn$(n,n)$
#
# ========================================================
# Found subentry 10817007 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 22083002 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 22083005 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{120}$Sn$(n,n)$
#
# ========================================================
# Found subentry 10633017 with the following columns:
# ['EN', 'DATA-ERR2', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ANG-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR1']
# Failed to parse subentry 10633017:
# 	Ambiguous statistical error labels:
# DATA-ERR2, MONIT-ERR, DATA-ERR1
# Found subentry 10817008 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 13158007 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 1 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{122}$Sn$(n,n)$
#
# ========================================================
# Found subentry 10817009 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{124}$Sn$(n,n)$
#
# ========================================================
# Found subentry 10817010 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{138}$Ba$(n,n)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{140}$Ce$(n,n)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{144}$Sm$(n,n)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{148}$Sm$(n,n)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{206}$Pb$(n,n)$
#
# ========================================================
# Found subentry 10633020 with the following columns:
# ['EN', 'DATA-ERR2', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ANG-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR1']
# Failed to parse subentry 10633020:
# 	Ambiguous statistical error labels:
# DATA-ERR2, MONIT-ERR, DATA-ERR1
# Found subentry 22048024 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 1 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{208}$Pb$(n,n)$
#
# ========================================================
# Found subentry 10871002 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Found subentry 12701005 with the following columns:
# ['DATA-ERR2', 'EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR1']
# Failed to parse subentry 12701005:
# 	Ambiguous statistical error labels:
# DATA-ERR2, DATA-ERR1
# Found subentry 12865002 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 13685002 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry 13946004 with the following columns:
# ['EN', 'EN-ERR', 'ANG-CM', 'DATA-CM', 'ERR-S', 'ERR-SYS']
# Found subentry 14317002 with the following columns:
# ['ERR-1', 'ERR-2', 'EN', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Failed to parse subentry 14317002:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-2, ERR-T
# Found subentry 14317003 with the following columns:
# ['ERR-1', 'ERR-2', 'EN', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Failed to parse subentry 14317003:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-2, ERR-T
# Found subentry 22847003 with the following columns:
# ['EN', 'EN-ERR', 'EN-RSL-FW', 'ERR-2', 'ERR-3', 'ANG-RSL', 'ANG-CM', 'DATA-CM', 'ERR-T', 'ERR-S', 'ERR-1']
# Failed to parse subentry 22847003:
# 	Ambiguous statistical error labels:
# ERR-2, ERR-3, ERR-T, ERR-S, ERR-1
# Found subentry 22987004 with the following columns:
# ['EN', 'EN-ERR', 'EN-RSL-FW', 'ERR-3', 'ANG-RSL', 'ANG-CM', 'DATA-CM', 'ERR-T', 'ERR-S', 'ERR-1']
# Failed to parse subentry 22987004:
# 	Ambiguous statistical error labels:
# ERR-3, ERR-T, ERR-S, ERR-1
#
# ========================================================
# Succesfully parsed 4 entries
# Failed to parse 4 entries:
#
# ========================================================

# %% [markdown]
# ## Parsing $(p,p)$ data

# %%
pp_data = dict(
    [
        (
            target,
            curate.MulltiQuantityReactionData(
                Reaction(target=target, projectile=proton),
                quantities=["dXS/dA", "dXS/dRuth"],
                settings=settings,
                vocal=True,
            ),
        )
        for target in targets
    ]
)
# Out:
# ========================================================
# Now parsing dXS/dA for $^{48}$Ca$(p,p)$
#
# ========================================================
# Found subentry C0624005 with the following columns:
# ['EN-ERR', 'ERR-SYS', 'ERR-7', 'ERR-9', 'EN', 'EN-ERR', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Failed to parse subentry C0624005:
# 	Ambiguous statistical error labels:
# ERR-SYS, ERR-7, ERR-9, DATA-ERR
# Found subentry E0166016 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry E0249008 with the following columns:
# ['EN', 'POL-BM-MIN', 'POL-BM-MAX', 'E-RSL', 'ANG-ERR', 'ANG-CM', 'ANG-RSL', 'DATA-CM', 'DATA-ERR']
# Found subentry O0032057 with the following columns:
# ['EN', 'ANG-CM', 'DATA', 'ERR-S']
# Found subentry O0387002 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
#
# ========================================================
# Succesfully parsed 4 entries
# Failed to parse 1 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{48}$Ca$(p,p)$
#
# ========================================================
# Found subentry O0239014 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry O0239016 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry O0239018 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{40}$Ca$(p,p)$
#
# ========================================================
# Found subentry C0076002 with the following columns:
# ['E-RSL', 'EN', 'ANG-CM', 'DATA-CM', 'ERR-S']
# Found subentry C0078002 with the following columns:
# ['EN-ERR', 'EN-RSL-FW', 'EN', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Found subentry C0624002 with the following columns:
# ['EN-ERR', 'ERR-SYS', 'ERR-7', 'ERR-9', 'EN', 'EN-ERR', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Failed to parse subentry C0624002:
# 	Ambiguous statistical error labels:
# ERR-SYS, ERR-7, ERR-9, DATA-ERR
# Found subentry C0893002 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-S']
# Found subentry E0166012 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry E0249002 with the following columns:
# ['EN', 'POL-BM-MIN', 'POL-BM-MAX', 'E-RSL', 'ANG-ERR', 'ANG-CM', 'ANG-RSL', 'DATA-CM', 'DATA-ERR']
# Found subentry E0795002 with the following columns:
# ['EN', 'ANG-CM', 'DATA']
# Warning: subentry E0795002 has no reported data errors
# Found subentry O0032002 with the following columns:
# ['EN', 'ANG-CM', 'DATA', 'ERR-S']
# Found subentry O0049004 with the following columns:
# ['EN', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ERR-T', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Failed to parse subentry O0049004:
# 	Ambiguous statistical error labels:
# MONIT-ERR, ERR-T, ERR-DIG
# Found subentry O0142004 with the following columns:
# ['EN', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Failed to parse subentry O0142004:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-T
# Found subentry O0208006 with the following columns:
# ['EN', 'ERR-1', 'ANG-ERR', 'ANG-CM', 'DATA-CM', 'ERR-2']
# Failed to parse subentry O0208006:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-2
# Found subentry O0211012 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA', 'ERR-T']
# Found subentry O0253002 with the following columns:
# ['EN-ERR', 'ERR-1', 'ERR-2', 'ERR-3', 'ANG-ERR-D', 'ERR-DIG', 'EN', 'ANG-CM', 'DATA-CM']
# Failed to parse subentry O0253002:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-2, ERR-3, ERR-DIG
# Found subentry O0254010 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
# Found subentry O0352002 with the following columns:
# ['EN', 'EN-RSL-HW', 'ANG-ERR', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Found subentry O0382002 with the following columns:
# ['EN', 'EN-RSL-FW', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Failed to parse subentry O0382002:
# 	Ambiguous statistical error labels:
# DATA-ERR, ERR-T
# Found subentry O0384002 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
# Found subentry O0384003 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
# Found subentry O0553004 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Found subentry O0553010 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Found subentry T0101002 with the following columns:
# ['DATA-ERR1', 'EN', 'ANG-CM', 'DATA', 'DATA-ERR']
# Failed to parse subentry T0101002:
# 	Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR
# Found subentry T0108005 with the following columns:
# ['EN', 'ANG-CM', 'DATA', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 13 entries
# Failed to parse 7 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{40}$Ca$(p,p)$
#
# ========================================================
# Found subentry E0120016 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM']
# Warning: subentry E0120016 has no reported data errors
# Found subentry E1677016 with the following columns:
# ['EN', 'ANG-CM', 'DATA', '+DATA-ERR', '-DATA-ERR']
# Failed to parse subentry E1677016:
# 	Ambiguous statistical error labels:
# +DATA-ERR, -DATA-ERR
# Found subentry O0211004 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA', 'ERR-T']
# Failed to parse subentry O0211004:
# 	Ambiguous statistical error labels:
# DATA-ERR, ERR-T
# Found subentry O0239002 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry O0239004 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry O0239006 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry O0253017 with the following columns:
# ['EN-ERR', 'ERR-1', 'ERR-2', 'ERR-3', 'ANG-ERR-D', 'ERR-DIG', 'EN', 'ANG-CM', 'DATA']
# Failed to parse subentry O0253017:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-2, ERR-3, ERR-DIG
# Found subentry O0302004 with the following columns:
# ['EN', 'DATA-ERR1', 'DATA-ERR2', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']
# Failed to parse subentry O0302004:
# 	Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR2, ERR-DIG
# Found subentry O1199007 with the following columns:
# ['EN-RSL', 'EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']
#
# ========================================================
# Succesfully parsed 3 entries
# Failed to parse 4 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{64}$Ni$(p,p)$
#
# ========================================================
# Found subentry C2165010 with the following columns:
# ['EN', 'EN-ERR', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry E0249032 with the following columns:
# ['EN', 'POL-BM-MIN', 'POL-BM-MAX', 'E-RSL', 'ANG-ERR', 'ANG-CM', 'ANG-RSL', 'DATA-CM', 'DATA-ERR']
# Found subentry E1201012 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry O0032065 with the following columns:
# ['EN', 'ANG-CM', 'DATA', 'ERR-S']
# Found subentry O0432003 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry O0458004 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
#
# ========================================================
# Succesfully parsed 6 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{64}$Ni$(p,p)$
#
# ========================================================
# Found subentry C1019019 with the following columns:
# ['ERR-S', 'EN', 'ANG-CM', 'DATA']
# Found subentry C1019040 with the following columns:
# ['ERR-S', 'EN', 'ANG-CM', 'DATA']
# Found subentry O0169004 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Found subentry O0432003 with the following columns:
# ['EN', 'ANG-CM', 'DATA']
# Warning: subentry O0432003 has no reported data errors
#
# ========================================================
# Succesfully parsed 3 entries
# Failed to parse 0 entries:
#
# ========================================================
# (64,28): found duplicates between (p,p) absolute and ratio to Rutherford in O0432
# [np.float64(11.7)]
# [np.float64(11.7)]
#
# ========================================================
# Now parsing dXS/dA for $^{86}$Sr$(p,p)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{86}$Sr$(p,p)$
#
# ========================================================
# Found subentry O0169006 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{88}$Sr$(p,p)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{88}$Sr$(p,p)$
#
# ========================================================
# Found subentry O0169008 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{90}$Zr$(p,p)$
#
# ========================================================
# Found subentry C0085002 with the following columns:
# ['EN', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry C0893028 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-S']
# Found subentry D0295002 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry E0166028 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry O0032021 with the following columns:
# ['EN', 'ANG-CM', 'DATA', 'ERR-S']
# Found subentry O0049009 with the following columns:
# ['EN', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ERR-T', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Failed to parse subentry O0049009:
# 	Ambiguous statistical error labels:
# MONIT-ERR, ERR-T, ERR-DIG
# Found subentry O0208008 with the following columns:
# ['EN', 'ERR-1', 'ANG-ERR', 'ANG-CM', 'DATA-CM', 'ERR-2']
# Failed to parse subentry O0208008:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-2
# Found subentry O0211015 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA', 'ERR-T']
# Found subentry O0351002 with the following columns:
# ['EN', 'ANG-CM', 'DATA', 'ERR-T']
# Found subentry O0372013 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
# Found subentry O0389002 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-2']
# Failed to parse subentry O0389002:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-2
# Found subentry T0101003 with the following columns:
# ['DATA-ERR1', 'EN', 'ANG-CM', 'DATA', 'DATA-ERR']
# Failed to parse subentry T0101003:
# 	Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR
#
# ========================================================
# Succesfully parsed 8 entries
# Failed to parse 4 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{90}$Zr$(p,p)$
#
# ========================================================
# Found subentry F0733003 with the following columns:
# ['EN', 'EN-ERR', 'ERR-DIG', 'ANG-ERR-D', 'ANG-CM', 'DATA-CM']
# Found subentry O0211007 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA', 'ERR-T']
# Failed to parse subentry O0211007:
# 	Ambiguous statistical error labels:
# DATA-ERR, ERR-T
# Found subentry O0300004 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']
# Found subentry O0370002 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
# Found subentry O0389002 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'ERR-1', 'ANG-CM', 'DATA']
# Failed to parse subentry O0389002:
# 	Ambiguous statistical error labels:
# ERR-1
# Found subentry O0788017 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR-D', 'ANG-CM', 'DATA', 'ERR-T']
# Found subentry O1825003 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-1', 'ERR-DIG', 'ANG-CM', 'DATA']
# Failed to parse subentry O1825003:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-DIG
#
# ========================================================
# Succesfully parsed 4 entries
# Failed to parse 3 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{92}$Zr$(p,p)$
#
# ========================================================
# Found subentry C0085004 with the following columns:
# ['EN', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry D0295006 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry O0372014 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
# Found subentry O0389022 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-2']
# Failed to parse subentry O0389022:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-2
# Found subentry T0108011 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry T0152002 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-S']
#
# ========================================================
# Succesfully parsed 5 entries
# Failed to parse 1 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{92}$Zr$(p,p)$
#
# ========================================================
# Found subentry O0389022 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'ERR-1', 'ANG-CM', 'DATA']
# Failed to parse subentry O0389022:
# 	Ambiguous statistical error labels:
# ERR-1
# Found subentry O0545002 with the following columns:
# ['EN', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry O0788015 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR-D', 'ANG-CM', 'DATA', 'ERR-T']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 1 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{94}$Zr$(p,p)$
#
# ========================================================
# Found subentry C0085005 with the following columns:
# ['EN', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry O0389033 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-2']
# Failed to parse subentry O0389033:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-2
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 1 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{94}$Zr$(p,p)$
#
# ========================================================
# Found subentry O0389033 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'ERR-1', 'ANG-CM', 'DATA']
# Failed to parse subentry O0389033:
# 	Ambiguous statistical error labels:
# ERR-1
# Found subentry O0545006 with the following columns:
# ['EN', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry O0788019 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR-D', 'ANG-CM', 'DATA', 'ERR-T']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 1 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{96}$Zr$(p,p)$
#
# ========================================================
# Found subentry C0085006 with the following columns:
# ['EN', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{96}$Zr$(p,p)$
#
# ========================================================
# Found subentry O0788018 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR-D', 'ANG-CM', 'DATA', 'ERR-T']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{92}$Mo$(p,p)$
#
# ========================================================
# Found subentry C0622002 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-S']
# Found subentry D0295010 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry O0549003 with the following columns:
# ['ANG-ERR', 'DATA-ERR', 'EN', 'ANG-CM', 'DATA']
# Found subentry T0289002 with the following columns:
# ['EN', 'EN-RSL-FW', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']
#
# ========================================================
# Succesfully parsed 4 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{92}$Mo$(p,p)$
#
# ========================================================
# Found subentry O0471007 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
# Found subentry O0581005 with the following columns:
# ['ANG-ERR', 'EN', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{94}$Mo$(p,p)$
#
# ========================================================
# Found subentry O0549005 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
# Found subentry T0289005 with the following columns:
# ['EN', 'EN-RSL-FW', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{94}$Mo$(p,p)$
#
# ========================================================
# Found subentry O0471008 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
# Found subentry O0580002 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA', 'ERR-S']
# Found subentry O0581006 with the following columns:
# ['ANG-ERR', 'EN', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
#
# ========================================================
# Succesfully parsed 3 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{116}$Sn$(p,p)$
#
# ========================================================
# Found subentry C0893030 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-S']
# Found subentry O0211016 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA', 'ERR-T']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{116}$Sn$(p,p)$
#
# ========================================================
# Found subentry C1019029 with the following columns:
# ['ERR-S', 'EN', 'ANG-CM', 'DATA']
# Found subentry O0169016 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Found subentry O0211008 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA', 'ERR-T']
# Failed to parse subentry O0211008:
# 	Ambiguous statistical error labels:
# DATA-ERR, ERR-T
# Found subentry O0434010 with the following columns:
# ['ERR-S', 'EN', 'ANG-ERR', 'DATA-ERR', 'ERR-S', 'ANG-CM', 'DATA']
# Failed to parse subentry O0434010:
# 	Error while parsing O0434010: Expected only one ERR-S column, found 2
# Found subentry O0788014 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR-D', 'ANG-CM', 'DATA', 'ERR-T']
#
# ========================================================
# Succesfully parsed 3 entries
# Failed to parse 2 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{118}$Sn$(p,p)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{118}$Sn$(p,p)$
#
# ========================================================
# Found subentry O0169018 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{120}$Sn$(p,p)$
#
# ========================================================
# Found subentry C0893032 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-S']
# Found subentry C2174002 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Found subentry C2174003 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Found subentry C2174004 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Found subentry C2174005 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Found subentry E2042007 with the following columns:
# ['POL-BM-MIN', 'POL-BM-MAX', 'EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry O0049010 with the following columns:
# ['EN', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ERR-T', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Failed to parse subentry O0049010:
# 	Ambiguous statistical error labels:
# MONIT-ERR, ERR-T, ERR-DIG
# Found subentry O0124004 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'DATA-ERR1', 'DATA-ERR2', 'ANG-CM', 'DATA', 'FLAG']
# Failed to parse subentry O0124004:
# 	Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR2
# Found subentry O0142010 with the following columns:
# ['EN', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Failed to parse subentry O0142010:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-T
# Found subentry T0108009 with the following columns:
# ['EN', 'ANG-CM', 'DATA', 'DATA-ERR']
# Found subentry T0152006 with the following columns:
# ['EN', 'ANG-CM', 'DATA', 'ERR-S']
#
# ========================================================
# Succesfully parsed 5 entries
# Failed to parse 3 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{120}$Sn$(p,p)$
#
# ========================================================
# Found subentry O0169020 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Found subentry O0169026 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Found subentry O0300005 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']
# Found subentry O0302006 with the following columns:
# ['EN', 'DATA-ERR1', 'DATA-ERR2', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']
# Failed to parse subentry O0302006:
# 	Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR2, ERR-DIG
# Found subentry O0328007 with the following columns:
# ['EN', 'EN-ERR', 'ERR-2', 'ERR-3', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA', 'ERR-1']
# Failed to parse subentry O0328007:
# 	Ambiguous statistical error labels:
# ERR-2, ERR-3, ERR-DIG, ERR-1
# Found subentry O0788010 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR-D', 'ANG-CM', 'DATA', 'ERR-T']
#
# ========================================================
# Succesfully parsed 3 entries
# Failed to parse 2 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{122}$Sn$(p,p)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{122}$Sn$(p,p)$
#
# ========================================================
# Found subentry O0169022 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Found subentry O0788013 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR-D', 'ANG-CM', 'DATA', 'ERR-T']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{124}$Sn$(p,p)$
#
# ========================================================
# Found subentry C0893034 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-S']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{124}$Sn$(p,p)$
#
# ========================================================
# Found subentry O0169024 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Found subentry O0788011 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR-D', 'ANG-CM', 'DATA', 'ERR-T']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{138}$Ba$(p,p)$
#
# ========================================================
# Found subentry C0893040 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-S']
# Found subentry O1894003 with the following columns:
# ['ANG-ERR', 'EN-ERR-DIG', 'ERR-DIG', 'ANG-CM', 'EN', 'DATA-CM']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{138}$Ba$(p,p)$
#
# ========================================================
# Found subentry C3001002 with the following columns:
# ['EN', 'EN-ERR', 'ANG-CM', 'DATA', 'FLAG']
# Warning: subentry C3001002 has no reported data errors
# Found subentry O2532003 with the following columns:
# ['EN', 'ANG-CM', 'DATA', 'DATA-ERR']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{140}$Ce$(p,p)$
#
# ========================================================
# Found subentry O0553012 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Found subentry O1894002 with the following columns:
# ['ANG-ERR', 'EN-ERR-DIG', 'ERR-DIG', 'ANG-CM', 'EN', 'DATA-CM']
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{140}$Ce$(p,p)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{144}$Sm$(p,p)$
#
# ========================================================
# Found subentry C3000002 with the following columns:
# ['EN', 'E-RSL-FW', 'ANG-CM', 'DATA-CM']
# Warning: subentry C3000002 has no reported data errors
# Found subentry E0773006 with the following columns:
# ['EN', 'POL-BM-MIN', 'POL-BM-MAX', 'ANG-CM', 'DATA-CM', 'DATA-CM']
# Failed to parse subentry E0773006:
# 	Error while parsing E0773006: Expected only one DATA column, found 2
# Found subentry E0904044 with the following columns:
# ['EN', 'POL-BM-MIN', 'POL-BM-MAX', 'ANG-CM', 'DATA-CM']
# Warning: subentry E0904044 has no reported data errors
# Found subentry O0032069 with the following columns:
# ['EN', 'ANG-CM', 'DATA', 'ERR-S']
#
# ========================================================
# Succesfully parsed 3 entries
# Failed to parse 1 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{144}$Sm$(p,p)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{148}$Sm$(p,p)$
#
# ========================================================
# Found subentry C1397002 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM']
# Warning: subentry C1397002 has no reported data errors
# Found subentry D0289002 with the following columns:
# ['EN', 'EN-RSL', 'ERR-DIG', 'DATA-ERR1', 'ERR-1', 'ERR-2', 'ANG-CM', 'DATA-CM', 'ERR-S']
# Failed to parse subentry D0289002:
# 	Ambiguous statistical error labels:
# ERR-DIG, DATA-ERR1, ERR-1, ERR-2, ERR-S
# Found subentry E0904046 with the following columns:
# ['EN', 'POL-BM-MIN', 'POL-BM-MAX', 'ANG-CM', 'DATA-CM']
# Warning: subentry E0904046 has no reported data errors
# Found subentry F1173002 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM', 'DATA-ERR2']
# Failed to parse subentry F1173002:
# 	Ambiguous statistical error labels:
# ERR-DIG, DATA-ERR2
#
# ========================================================
# Succesfully parsed 2 entries
# Failed to parse 2 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{148}$Sm$(p,p)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{206}$Pb$(p,p)$
#
# ========================================================
#
# ========================================================
# Succesfully parsed 0 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{206}$Pb$(p,p)$
#
# ========================================================
# Found subentry O0788008 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR-D', 'ANG-CM', 'DATA', 'ERR-T']
#
# ========================================================
# Succesfully parsed 1 entries
# Failed to parse 0 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dA for $^{208}$Pb$(p,p)$
#
# ========================================================
# Found subentry C0081005 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry C0893042 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'ERR-S']
# Found subentry E1201014 with the following columns:
# ['EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Found subentry E1846023 with the following columns:
# ['EN-RSL', 'E-RSL', 'E-LVL-ERR', 'EN', 'ANG-CM', 'DATA-CM']
# Warning: subentry E1846023 has no reported data errors
# Found subentry O0032025 with the following columns:
# ['EN', 'ANG-CM', 'DATA', 'ERR-S']
# Found subentry O0049012 with the following columns:
# ['EN', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ERR-T', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']
# Failed to parse subentry O0049012:
# 	Ambiguous statistical error labels:
# MONIT-ERR, ERR-T, ERR-DIG
# Found subentry O0142011 with the following columns:
# ['EN', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-T']
# Failed to parse subentry O0142011:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-T
# Found subentry O0157004 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry O0166023 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']
# Found subentry O0208009 with the following columns:
# ['EN', 'ERR-1', 'ANG-ERR', 'ANG-CM', 'DATA-CM', 'ERR-2']
# Failed to parse subentry O0208009:
# 	Ambiguous statistical error labels:
# ERR-1, ERR-2
# Found subentry O0211017 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA', 'ERR-T']
# Found subentry O0225146 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
# Found subentry O0272002 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA']
# Found subentry O0285002 with the following columns:
# ['EN', 'EN-RSL-FW', 'DATA-ERR', 'MONIT', 'MONIT-ERR', 'ANG-CM', 'DATA-CM']
# Failed to parse subentry O0285002:
# 	Ambiguous statistical error labels:
# DATA-ERR, MONIT-ERR
# Found subentry T0101004 with the following columns:
# ['DATA-ERR1', 'EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# Failed to parse subentry T0101004:
# 	Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR
#
# ========================================================
# Succesfully parsed 10 entries
# Failed to parse 5 entries:
#
# ========================================================
#
# ========================================================
# Now parsing dXS/dRuth for $^{208}$Pb$(p,p)$
#
# ========================================================
# Found subentry C1019035 with the following columns:
# ['ERR-S', 'EN', 'ANG-CM', 'DATA']
# Found subentry O0211009 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA', 'ERR-T']
# Failed to parse subentry O0211009:
# 	Ambiguous statistical error labels:
# DATA-ERR, ERR-T
# Found subentry O0287002 with the following columns:
# ['EN', 'ERR-1', 'DATA-ERR', 'EN-RSL-FW', 'ANG-CM', 'DATA']
# Failed to parse subentry O0287002:
# 	Ambiguous statistical error labels:
# ERR-1, DATA-ERR
# Found subentry O0300002 with the following columns:
# ['EN', 'ERR-DIG', 'ANG-CM', 'DATA']
# Found subentry O0302002 with the following columns:
# ['EN', 'DATA-ERR1', 'DATA-ERR2', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']
# Failed to parse subentry O0302002:
# 	Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR2, ERR-DIG
# Found subentry O0490012 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA-CM']
# Found subentry O0552008 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA', 'ERR-T']
# Failed to parse subentry O0552008:
# 	Ambiguous statistical error labels:
# DATA-ERR, ERR-T
# Found subentry O0788009 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR-D', 'ANG-CM', 'DATA', 'ERR-T']
#
# ========================================================
# Succesfully parsed 4 entries
# Failed to parse 4 entries:
#
# ========================================================

# %% [markdown]
# Wow, that's a lot of information!
#
# ## Let's step through the targets one by one, handling any failed parses our outliers, and plotting the data

# %%
def check_measurements_for_errs(entry):
    for m in entry.measurements:
        if np.allclose(m.statistical_err, 0):
            print(f"subentry {m.subentry} is missing statisitcal errors!")


def flag_entries(target):

    for entry_id, entry in nn_data[target].data["dXS/dA"].entries.items():
        check_measurements_for_errs(entry)
        if entry_id in entries_to_ignore_nn:
            print(f"Look at entry {entry_id} for (n,n)")

    for entry_id, entry in nn_data[target].data["dXS/dA"].failed_parses.items():
        check_measurements_for_errs(entry)
        if entry_id in entries_to_ignore_nn:
            print(f"Look at failed parse {entry_id} for (n,n)")

    for entry_id, entry in pp_data[target].data["dXS/dA"].entries.items():
        check_measurements_for_errs(entry)

        if entry_id in entries_to_ignore_pp_absolute:
            print(f"Look at entry {entry_id} for (p,p) absolute")

    for entry_id, entry in pp_data[target].data["dXS/dA"].failed_parses.items():
        check_measurements_for_errs(entry)
        if entry_id in entries_to_ignore_pp_absolute:
            print(f"Look at failed parse {entry_id} for (p,p) absolute")

    for entry_id, entry in pp_data[target].data["dXS/dRuth"].entries.items():
        check_measurements_for_errs(entry)

        if entry_id in entries_to_ignore_pp_Ruth:
            print(f"Look at entry {entry_id} for (p,p) ratio")
    for entry_id, entry in pp_data[target].data["dXS/dRuth"].failed_parses.items():
        check_measurements_for_errs(entry)

        if entry_id in entries_to_ignore_pp_Ruth:
            print(f"Look at failed parse {entry_id} for (p,p) ratio")

# %% [markdown]
# ## $^{48}$Ca

# %%
target = Ca48
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 2}
# Number of (p,p) measurements: {'dXS/dA': 4, 'dXS/dRuth': 3}
# Look at entry E0249 for (p,p) absolute
# Look at entry O0032 for (p,p) absolute

# %%
print(pp_data[target].data["dXS/dA"].entries.keys())
del pp_data[target].data["dXS/dA"].entries["E0249"]
del pp_data[target].data["dXS/dA"].entries["O0032"]
print(pp_data[target].data["dXS/dA"].entries.keys())
# Out:
# dict_keys(['E0166', 'E0249', 'O0032', 'O0387'])
# dict_keys(['E0166', 'O0387'])

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()
# Out:
# Entry: C0624
# C0624005  :  Ambiguous statistical error labels:
# ERR-SYS, ERR-7, ERR-9, DATA-ERR
# ERR-ANALYS (DATA-ERR) Relative uncertainty.
#            (ERR-S,,1.) Statistical uncertainty <1%.
#             Systematic uncertainties:
#            (ERR-1,,1.) Dead time correction                 <1.0%
#            (ERR-2,,0.1)  Correction for reaction losses
#                                                  in NaI(Tl) <0.1%
#            (ERR-3,,0.3)  Finite geometry correction         <0.3%
#            (ERR-4,,1.)  Detector angle                      <1.0%
#            (ERR-5,,1.5)  Incident proton energy             <1.5%
#            (ERR-6,,2.)  Impurity subtraction - worst case    2.0%
#            (ERR-SYS) Uncertainty in the absolute scale includes:
#            (ERR-7) Uncertainty in the detector solid angle
#            (ERR-8,,1.) Uncertainty in the target rotation angle
#            (ERR-9) Uncertainty in the beam current integration
#             * Uncertainty in the target thickness

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "C0624",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR"],
        "systematic_err_labels": ["ERR-SYS"],
    },
)
# Out:
# Found subentry C0624005 with the following columns:
# ['EN-ERR', 'ERR-SYS', 'ERR-7', 'ERR-9', 'EN', 'EN-ERR', 'ANG-CM', 'DATA-CM', 'DATA-ERR']

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={"label_exfor": True, "label_offset_factor": 0.05},
        plot_kwargs={"offsets": 10},
        y_size=6,
    )
)
axes[0].set_xlim([-5, 220])
# Out:
# (-5.0, 220.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={"label_exfor": True, "label_offset_factor": 0.0003},
        plot_kwargs={"offsets": 100},
        y_size=8,
    )
)
axes[0].set_xlim([-5, 220])
# Out:
# (-5.0, 220.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1.5,
            "label_xloc_deg": 0,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=5,
    )
)
axes[0].set_xlim([-20, 220])
# Out:
# (-20.0, 220.0)

# %% [markdown]
# ## $^{40}$Ca

# %%
target = Ca40
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 14}
# Number of (p,p) measurements: {'dXS/dA': 19, 'dXS/dRuth': 5}
# Look at entry C0078 for (p,p) absolute
# Look at entry E0249 for (p,p) absolute
# subentry E0795002 is missing statisitcal errors!
# Look at entry E0795 for (p,p) absolute
# Look at entry O0032 for (p,p) absolute
# Look at failed parse O0253 for (p,p) absolute
# subentry E0120016 is missing statisitcal errors!
# Look at entry E0120 for (p,p) ratio

# %%
# Exclusions:
del pp_data[target].data["dXS/dA"].entries["C0078"]  # redundant, huge uncertainties
del pp_data[target].data["dXS/dA"].entries["E0795"]  # duplicate, no uncertainties
del pp_data[target].data["dXS/dA"].entries["O0032"]  # duplicate to E0166 and E0249
del pp_data[target].data["dXS/dA"].entries["E0249"]  # duplicate to E0166 and O0032
del pp_data[target].data["dXS/dRuth"].entries["E0120"]  # no uncertainties
del pp_data[target].data["dXS/dA"].failed_parses["O0253"]
# duplicate to Rutherford from same entry, some data shows Compound Elastic effects per original paper

# %%
# del pp_data[target].data["dXS/dRuth"].entries["E0120"]  # no errors reported

# %% [markdown]
# ### handling failed parses

# %%
curate.print_failed_parses(nn_data[target].data["dXS/dA"].failed_parses)

# %%
curate.print_failed_parses(pp_data[target].data["dXS/dRuth"].failed_parses)
# Out:
# Entry: E1677
# E1677016  :  Ambiguous statistical error labels:
# +DATA-ERR, -DATA-ERR
# ERR-ANALYS (DATA-ERR) No information on source of uncertainties.
# ERR-ANALYS (ERR-S,,5.) Statistical error <5%
# Entry: O0211
# O0211004  :  Ambiguous statistical error labels:
# DATA-ERR, ERR-T
#
# ERR-ANALYS (ERR-T).The Uncertainty is Reported by Authors.
#            (DATA-ERR).Data-Point Reader Uncertainty.
#            (ANG-ERR).Data-Point Reader Uncertainty.
# Entry: O0253
# O0253017  :  Ambiguous statistical error labels:
# ERR-1, ERR-2, ERR-3, ERR-DIG
# ERR-ANALYS (ERR-1) Relative uncertainties
#            (ERR-2) Absolute uncertainty
#            (ERR-3) the uncertainty in the corrections for carbon
#            and oxygen at forward angles
#
# Entry: O0302
# O0302004  :  Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR2, ERR-DIG
# ERR-ANALYS  The statistical error varied from 1 % at
#             small angles to 4 % at 50 degrees.
#            (DATA-ERR1) The overall error was calculated to
#             be +/- 5% for the relative cross sections and
#            (DATA-ERR2)  +/-7 % for the absolute cross sections.
#            (20201204A) SD: Data were re-digitized. ERR-ANALYS
#            deleted. STATUS updated.

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "E1677",
    parsing_kwargs={
        "statistical_err_labels": ["+DATA-ERR", "-DATA-ERR"],
        "statistical_err_treatment": "difference",
    },
)
# Out:
# Found subentry E1677016 with the following columns:
# ['EN', 'ANG-CM', 'DATA', '+DATA-ERR', '-DATA-ERR']

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O0211",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR", "ERR-T"],
    },
)
# Out:
# Found subentry O0211004 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA', 'ERR-T']

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O0253",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-1", "ERR-DIG"],
        "systematic_err_labels": ["ERR-2"],
    },
)
# Out:
# Found subentry O0253017 with the following columns:
# ['EN-ERR', 'ERR-1', 'ERR-2', 'ERR-3', 'ANG-ERR-D', 'ERR-DIG', 'EN', 'ANG-CM', 'DATA']

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O0302",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR1", "ERR-DIG"],
        "systematic_err_labels": ["DATA-ERR2"],
    },
)
# Out:
# Found subentry O0302004 with the following columns:
# ['EN', 'DATA-ERR1', 'DATA-ERR2', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']

# %%
curate.print_failed_parses(pp_data[target].data["dXS/dA"].failed_parses)
# Out:
# Entry: C0624
# C0624002  :  Ambiguous statistical error labels:
# ERR-SYS, ERR-7, ERR-9, DATA-ERR
# ERR-ANALYS (DATA-ERR) Relative uncertainty.
#            (ERR-S,,1.) Statistical uncertainty <1%.
#             Systematic uncertainties:
#            (ERR-1,,1.) Dead time correction                 <1.0%
#            (ERR-2,,0.1)  Correction for reaction losses
#                                                  in NaI(Tl) <0.1%
#            (ERR-3,,0.3)  Finite geometry correction         <0.3%
#            (ERR-4,,1.)  Detector angle                      <1.0%
#            (ERR-5,,1.5)  Incident proton energy             <1.5%
#            (ERR-6,,2.)  Impurity subtraction - worst case    2.0%
#            (ERR-SYS) Uncertainty in the absolute scale includes:
#            (ERR-7) Uncertainty in the detector solid angle
#            (ERR-8,,1.) Uncertainty in the target rotation angle
#            (ERR-9) Uncertainty in the beam current integration
#             * Uncertainty in the target thickness
#
# Entry: O0049
# O0049004  :  Ambiguous statistical error labels:
# MONIT-ERR, ERR-T, ERR-DIG
# ERR-ANALYS (ERR-S,1.,6.) The statistical errors for the cross
#            sections were 1 to 2% for ang. < 25. degr. and 3 to 6%
#            for ang. > 25.degr.
#            (ERR-T) The overall uncertainty
#
# Entry: O0142
# O0142004  :  Ambiguous statistical error labels:
# ERR-1, ERR-T
# ERR-ANALYS ERRORS QUOTED AGAINST INDIVIDUAL MEASUREMENTS ARE
#            RELATIVE ERRORS WITHIN EACH ANGULAR DISTRIBUTION AND
#            WERE COMPOUNDED FROM THEC FOLLOWING CONTRIBUTIONS-
#            STATISTICAL ERROR ON THE NUMBER OF COUNTS IN THE
#            ELASTIC PEAK,ERROR IN COUNTING LOSS CORRECTIONS,ERROR
#            IN CORRECTION FOR SCATTERING BY IMPURITIES,DUE MAINLY
#            TO UNCERTAINTY IN THE AMOUNT OF CONTAMINATION,RESIDUAL
#            UNCERTAINTY IN SCATTERING ANGLE AFTER CORRECTIONS HAD
#            BEEN MADE.THIS WAS TRANSFORMED TO AN ERROR IN CROSS
#            SECTION AT THE NOMINAL SCATTERING ANGLE.
#            (ERR-T).THE UNCERTAINTY IS REPORTED BY AUTHORS.
#            (ERR-1). THE UNCERTAINTY OF THE NORMALIZATION. THIS
#            ARISES ALMOST ENTIRELY FROM INACCURACYIN
#            DETERMINATIONOF THE SUPERFICIAL OF TARGET.
#
# Entry: O0208
# O0208006  :  Ambiguous statistical error labels:
# ERR-1, ERR-2
# ERR-ANALYS (ERR-1) Uncertainty in the target thickness.
# ERR-ANALYS (ERR-2) Relative error include all sources of error
#            except uncertainty in the target thickness.
# Entry: O0382
# O0382002  :  Ambiguous statistical error labels:
# DATA-ERR, ERR-T
# ERR-ANALYS (ANG-ERR).Data-Point Reader Uncertainty.
# ERR-ANALYS (ERR-T).The Uncertainty is Shown on Figure by Authors.
#            (DATA-ERR).Data-Point Reader Uncertainty.
# Entry: T0101
# T0101002  :  Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR
# ERR-ANALYS (DATA-ERR) Total systematic error, arising from
#             uncertainties in target thickness, charge integration,
#             target angle and spectrograph solid angle estimated
#             to be about 8-10%.
#            Relative errors from all sources were combined in
#             quadrature to obtain total relative uncertainty
#             which was typically 2-3% at angles less than 60
#             degrees. Relative uncertainty arose mainly from
#             following sources:
#             . Statistical errors (typically 1-2%, and rarely
#               larger than 10%),
#             . Deadtime uncertainty (kept below 1%),
#             . Uncertainty in charge collection (up to 1 %
#               at forward angles),
#             . uncertainties in the effective scattering angle and
#               uncertainty in the zero-degree angle (<7%).
#             . additional contribution from unknown sources (1%).
#            Angle error estimated to be 0.03 degrees.

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "C0624",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR"],
        "systematic_err_labels": ["ERR-SYS"],
    },
)
# Out:
# Found subentry C0624002 with the following columns:
# ['EN-ERR', 'ERR-SYS', 'ERR-7', 'ERR-9', 'EN', 'EN-ERR', 'ANG-CM', 'DATA-CM', 'DATA-ERR']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0049",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-DIG", "ERR-T"],
        "systematic_err_labels": ["MONIT-ERR"],
    },
)
# Out:
# Found subentry O0049004 with the following columns:
# ['EN', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ERR-T', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0142",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-T"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry O0142004 with the following columns:
# ['EN', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-T']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0208",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-2"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry O0208006 with the following columns:
# ['EN', 'ERR-1', 'ANG-ERR', 'ANG-CM', 'DATA-CM', 'ERR-2']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0382",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-T", "DATA-ERR"],
    },
)
# Out:
# Found subentry O0382002 with the following columns:
# ['EN', 'EN-RSL-FW', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA-CM', 'ERR-T']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "T0101",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR"],
        "systematic_err_labels": ["DATA-ERR1"],
    },
)
# Out:
# Found subentry T0101002 with the following columns:
# ['DATA-ERR1', 'EN', 'ANG-CM', 'DATA', 'DATA-ERR']

# %% [markdown]
# ### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        n_per_plot=6,
        label_kwargs={
            "label_xloc_deg": -19,
            "label_offset_factor": 0.1,
            "label_energy_err": False,
            "label_offset": False,
            "label_incident_energy": True,
            "label_excitation_energy": False,
            "label_exfor": True,
        },
        plot_kwargs={"offsets": 10},
        y_size=8,
    )
)
axes[0].set_xlim([-20, 180])
axes[1].set_xlim([-20, 30])
# Out:
# (-20.0, 30.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        n_per_plot=10,
        label_kwargs={
            "label_xloc_deg": None,
            "label_offset_factor": 0.002,
            "label_offset": True,
            "label_exfor": True,
        },
        plot_kwargs={"offsets": 100},
        y_size=10,
    )
)
[a.set_xlim([-5, 220]) for a in axes]
# Out:
# [(-5.0, 220.0), (-5.0, 220.0), (-5.0, 220.0)]

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        n_per_plot=9,
        label_kwargs={
            "label_xloc_deg": None,
            "label_offset_factor": 2.5,
            "label_offset": True,
            "label_exfor": True,
        },
        plot_kwargs={"offsets": 5, "log": False, "draw_baseline": True},
        y_size=10,
    )
)
[a.set_xlim([-5, 220]) for a in axes]
# Out:
# [(-5.0, 220.0), (-5.0, 220.0)]

# %% [markdown]
# ## $^{138}$Ba

# %%
target = Ba138
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 0}
# Number of (p,p) measurements: {'dXS/dA': 1, 'dXS/dRuth': 2}
# subentry C3001002 is missing statisitcal errors!
# Look at entry C3001 for (p,p) ratio

# %%
del pp_data[target].data['dXS/dRuth'].entries['C3001']

# %% [markdown]
# #### failed parses

# %%
curate.print_failed_parses(nn_data[target].data["dXS/dA"].failed_parses)

# %%
curate.print_failed_parses(pp_data[target].data["dXS/dRuth"].failed_parses)

# %%
curate.print_failed_parses(pp_data[target].data["dXS/dA"].failed_parses)

# %% [markdown]
# #### plotting

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        n_per_plot=6,
        label_kwargs={
            "label_xloc_deg": 90,
            "label_offset_factor": 0.1,
            "label_energy_err": False,
            "label_offset": False,
            "label_incident_energy": True,
            "label_excitation_energy": False,
            "label_exfor": True,
        },
        plot_kwargs={"offsets": 10},
        y_size=4,
    )
)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        n_per_plot=2,
        label_kwargs={
            "label_xloc_deg": 90,
            "label_offset_factor": 1 / 2,
            "label_offset": True,
            "label_exfor": True,
        },
        plot_kwargs={
            "offsets": 1,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=6,
    )
)
axes[0].set_xlim([0, 120])
# Out:
# (0.0, 120.0)

# %% [markdown]
# ## $^{130}$Ce

# %%
target = Ce140
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 0}
# Number of (p,p) measurements: {'dXS/dA': 2, 'dXS/dRuth': 0}

# %% [markdown]
# #### failed parses

# %%
curate.print_failed_parses(nn_data[target].data["dXS/dA"].failed_parses)

# %%
curate.print_failed_parses(pp_data[target].data["dXS/dRuth"].failed_parses)

# %%
curate.print_failed_parses(pp_data[target].data["dXS/dA"].failed_parses)

# %% [markdown]
# #### plotting

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        n_per_plot=6,
        label_kwargs={
            "label_xloc_deg": 30,
            "label_offset_factor": 0.1,
            "label_energy_err": False,
            "label_offset": False,
            "label_incident_energy": True,
            "label_excitation_energy": False,
            "label_exfor": True,
        },
        plot_kwargs={"offsets": 10},
        y_size=4,
    )
)
axes[0].set_xlim([0, 45])
# Out:
# (0.0, 45.0)

# %% [markdown]
# ## $^{206}$Pb

# %%
target = Pb206
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 1}
# Number of (p,p) measurements: {'dXS/dA': 0, 'dXS/dRuth': 1}

# %% [markdown]
# #### failed parses

# %%
curate.print_failed_parses(nn_data[target].data["dXS/dA"].failed_parses)
# Out:
# Entry: 10633
# 10633020  :  Ambiguous statistical error labels:
# DATA-ERR2, MONIT-ERR, DATA-ERR1
# ERR-ANALYS (DATA-ERR1) Relative uncertainties
#            (DATA-ERR2) Normalization error

# %%
nn_data[target].data["dXS/dA"].reattempt_parse(
    "10633",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR1"],
        "systematic_err_labels": ["DATA-ERR2"],
    },
)
# Out:
# Found subentry 10633020 with the following columns:
# ['EN', 'DATA-ERR2', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ANG-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR1']

# %%
curate.print_failed_parses(pp_data[target].data["dXS/dRuth"].failed_parses)

# %%
curate.print_failed_parses(pp_data[target].data["dXS/dA"].failed_parses)

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        n_per_plot=6,
        label_kwargs={
            "label_xloc_deg": -19,
            "label_offset_factor": 0.1,
            "label_energy_err": False,
            "label_offset": False,
            "label_incident_energy": True,
            "label_excitation_energy": False,
            "label_exfor": True,
        },
        plot_kwargs={"offsets": 100},
        y_size=6,
    )
)
axes[0].set_xlim([-21, 180])
# Out:
# (-21.0, 180.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        n_per_plot=2,
        label_kwargs={
            "label_xloc_deg": 45,
            "label_offset_factor": 1 / 2,
            "label_offset": True,
            "label_exfor": True,
        },
        plot_kwargs={
            "offsets": 1,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=4,
    )
)
axes[0].set_xlim([0, 100])
# Out:
# (0.0, 100.0)

# %% [markdown]
# ## $^{208}$Pb

# %%
target = Pb208
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 16}
# Number of (p,p) measurements: {'dXS/dA': 10, 'dXS/dRuth': 4}
# Look at failed parse 14317 for (n,n)
# subentry E1846023 is missing statisitcal errors!
# Look at entry O0032 for (p,p) absolute
# Look at entry O0490 for (p,p) ratio

# %%
del pp_data[target].data['dXS/dA'].entries['E1846']

# %%
del nn_data[target].data["dXS/dA"].failed_parses["14317"]  # duplicate
del pp_data[target].data["dXS/dRuth"].entries["O0490"]
del pp_data[target].data["dXS/dA"].entries["O0032"]
del nn_data[target].data["dXS/dA"].failed_parses["14317"]  # duplicate
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 4
#       2 del pp_data[target].data["dXS/dRuth"].entries["O0490"]
#       3 del pp_data[target].data["dXS/dA"].entries["O0032"]
# ----> 4 del nn_data[target].data["dXS/dA"].failed_parses["14317"]  # duplicate
#
# KeyError: '14317'

# %% [markdown]
# #### failed parses

# %%
curate.print_failed_parses(nn_data[target].data["dXS/dA"].failed_parses)

# %%
nn_data[target].data["dXS/dA"].reattempt_parse(
    "12701",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR1"],
        "systematic_err_labels": ["DATA-ERR2"],
    },
)

# %%
nn_data[target].data["dXS/dA"].reattempt_parse(
    "22847",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-T"],
        "systematic_err_labels": ["ERR-2"],
    },
)

# %%
nn_data[target].data["dXS/dA"].reattempt_parse(
    "22987",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-T"],
        "systematic_err_labels": ["ERR-1", "ERR-3"],
    },
)

# %%
curate.print_failed_parses(pp_data[target].data["dXS/dRuth"].failed_parses)
# Out:
# Entry: O0211
# O0211009  :  Ambiguous statistical error labels:
# DATA-ERR, ERR-T
#
# ERR-ANALYS (ERR-T).The Uncertainty is Reported by Authors.
#            (DATA-ERR).Data-Point Reader Uncertainty.
#            (ANG-ERR).Data-Point Reader Uncertainty.
# Entry: O0287
# O0287002  :  Ambiguous statistical error labels:
# ERR-1, DATA-ERR
#
# ERR-ANALYS (ERR-1) The Absolute Uncertainty in the Cross Sections
#             Was 8.3 %, Including the Errors in the Calibration
#             Procedure and the Target Thickness Determination.
# Entry: O0302
# O0302002  :  Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR2, ERR-DIG
# ERR-ANALYS  The statistical error varied from 1 % at
#             small angles to 4 % at 50 degrees.
#            (DATA-ERR1) The overall error was calculated to
#             be +/- 5% for the relative cross sections and
#            (DATA-ERR2)  +/-7 % for the absolute cross sections.
#            (19970526A) ERR-ANALYS and COMMENT are included.
#            (20040630U) Last checking has been done.
#            (20201204A) SD: Data were re-digitized. ERR-ANALYS
#            (20201204A) SD: Data were re-digitized. ERR-ANALYS
#            deleted. STATUS updated. COMMENT deleted.
# Entry: O0552
# O0552008  :  Ambiguous statistical error labels:
# DATA-ERR, ERR-T
# ERR-ANALYS There are Several Contributions to the Uncertainty in
#            The Relative Cross Section Measurements in Addition to
#            Statistical Uncertainties.One Contribution is the Error
#            In the Cross Section Caused by the Uncertainty in the
#            Angle of the Detectors.The Total Uncertainty in the
#            Relative Cross Section Measurements Ranges from 0.5%
#            To 0.3%. The Uncertainties in the Polarization Range
#            From 0.002 to 0.001.
# ERR-ANALYS (ERR-T).The Uncertainty is Shown by Authors on Figures.
#            (DATA-ERR).Data-Point Reader Uncertainty.
#            (ANG-ERR).Data-Point Reader Uncertainty.

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O0211",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR", "ERR-T"],
    },
)
# Out:
# Found subentry O0211009 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA', 'ERR-T']

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O0287",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry O0287002 with the following columns:
# ['EN', 'ERR-1', 'DATA-ERR', 'EN-RSL-FW', 'ANG-CM', 'DATA']

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O0302",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR1", "ERR-DIG"],
        "systematic_err_labels": ["DATA-ERR2"],
    },
)
# Out:
# Found subentry O0302002 with the following columns:
# ['EN', 'DATA-ERR1', 'DATA-ERR2', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O0552",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR", "ERR-T"],
    },
)
# Out:
# Found subentry O0552008 with the following columns:
# ['EN', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA', 'ERR-T']

# %%
curate.print_failed_parses(pp_data[target].data["dXS/dA"].failed_parses)
# Out:
# Entry: O0049
# O0049012  :  Ambiguous statistical error labels:
# MONIT-ERR, ERR-T, ERR-DIG
# ERR-ANALYS (ERR-S,1.,6.) The statistical errors for the cross
#            sections were 1 to 2% for ang. < 25. degr. and 3 to 6%
#            for ang. > 25.degr.
#            (ERR-T) The overall uncertainty
#
# Entry: O0142
# O0142011  :  Ambiguous statistical error labels:
# ERR-1, ERR-T
# ERR-ANALYS ERRORS QUOTED AGAINST INDIVIDUAL MEASUREMENTS ARE
#            RELATIVE ERRORS WITHIN EACH ANGULAR DISTRIBUTION AND
#            WERE COMPOUNDED FROM THEC FOLLOWING CONTRIBUTIONS-
#            STATISTICAL ERROR ON THE NUMBER OF COUNTS IN THE
#            ELASTIC PEAK,ERROR IN COUNTING LOSS CORRECTIONS,ERROR
#            IN CORRECTION FOR SCATTERING BY IMPURITIES,DUE MAINLY
#            TO UNCERTAINTY IN THE AMOUNT OF CONTAMINATION,RESIDUAL
#            UNCERTAINTY IN SCATTERING ANGLE AFTER CORRECTIONS HAD
#            BEEN MADE.THIS WAS TRANSFORMED TO AN ERROR IN CROSS
#            SECTION AT THE NOMINAL SCATTERING ANGLE.
#            (ERR-T).THE UNCERTAINTY IS REPORTED BY AUTHORS.
#            (ERR-1). THE UNCERTAINTY OF THE NORMALIZATION. THIS
#            ARISES ALMOST ENTIRELY FROM INACCURACYIN
#            DETERMINATIONOF THE SUPERFICIAL OF TARGET.
#
# Entry: O0208
# O0208009  :  Ambiguous statistical error labels:
# ERR-1, ERR-2
# ERR-ANALYS (ERR-1) Uncertainty in the target thickness.
# ERR-ANALYS (ERR-2) Relative error include all sources of error
#            except uncertainty in the target thickness.
# Entry: O0285
# O0285002  :  Ambiguous statistical error labels:
# DATA-ERR, MONIT-ERR
# ERR-ANALYS (DATA-ERR) An Estimated 5 Percent Error from the Scan
#             Of the Figures.
#
# Entry: T0101
# T0101004  :  Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR
# ERR-ANALYS (DATA-ERR) Total systematic error, arising from
#             uncertainties in target thickness, charge integration,
#             target angle and spectrograph solid angle estimated
#             to be about 8-10%.
#            Relative errors from all sources were combined in
#             quadrature to obtain total relative uncertainty
#             which was typically 2-3% at angles less than 60
#             degrees. Relative uncertainty arose mainly from
#             following sources:
#             . Statistical errors (typically 1-2%, and rarely
#               larger than 10%),
#             . Deadtime uncertainty (kept below 1%),
#             . Uncertainty in charge collection (up to 1 %
#               at forward angles),
#             . uncertainties in the effective scattering angle and
#               uncertainty in the zero-degree angle (<7%).
#             . additional contribution from unknown sources (1%).
#            Angle error estimated to be 0.03 degrees.

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0049",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-DIG", "ERR-T"],
        "systematic_err_labels": ["MONIT-ERR"],
    },
)
# Out:
# Found subentry O0049012 with the following columns:
# ['EN', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ERR-T', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0142",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-T"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry O0142011 with the following columns:
# ['EN', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-T']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0208",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-2"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry O0208009 with the following columns:
# ['EN', 'ERR-1', 'ANG-ERR', 'ANG-CM', 'DATA-CM', 'ERR-2']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0285",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR"],
        "systematic_err_labels": ["MONIT-ERR"],
    },
)
# Out:
# Found subentry O0285002 with the following columns:
# ['EN', 'EN-RSL-FW', 'DATA-ERR', 'MONIT', 'MONIT-ERR', 'ANG-CM', 'DATA-CM']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "T0101",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR"],
        "systematic_err_labels": ["DATA-ERR1"],
    },
)
# Out:
# Found subentry T0101004 with the following columns:
# ['DATA-ERR1', 'EN', 'ANG-CM', 'DATA-CM', 'DATA-ERR']

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        n_per_plot=9,
        label_kwargs={
            "label_xloc_deg": 65,
            "label_offset_factor": 0.1,
            "label_energy_err": False,
            "label_offset": False,
            "label_incident_energy": True,
            "label_excitation_energy": False,
            "label_exfor": True,
        },
        plot_kwargs={"offsets": 100},
        y_size=8,
    )
)
axes[1].set_xlim([0, 90])
# Out:
# (0.0, 90.0)

# %% [markdown]
# Looks like there may be mis-transcribed data points in `12701`:

# %%
print([m.Einc for m in nn_data[target].data["dXS/dA"].entries["12701"].measurements])

print(nn_data[target].data["dXS/dA"].entries["12701"].measurements[1].y[:5])
nn_data[target].data["dXS/dA"].entries["12701"].measurements[1].y[1] *= 10
# nn_data[target].data['dXS/dA'].entries['12701'].measurements[1].statistical_err[1] *= 10
nn_data[target].data["dXS/dA"].entries["12701"].measurements[1].notes = [
    "2nd point increased by a factor of 10"
]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 print([m.Einc for m in nn_data[target].data["dXS/dA"].entries["12701"].measurements])
#       3 print(nn_data[target].data["dXS/dA"].entries["12701"].measurements[1].y[:5])
#       4 nn_data[target].data["dXS/dA"].entries["12701"].measurements[1].y[1] *= 10
#
# KeyError: '12701'

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        n_per_plot=10,
        label_kwargs={
            "label_xloc_deg": 120,
            "label_offset_factor": 0.001,
            "label_energy_err": False,
            "label_offset": False,
            "label_incident_energy": True,
            "label_excitation_energy": False,
            "label_exfor": True,
        },
        plot_kwargs={"offsets": 100},
        y_size=8,
    )
)

# %% [markdown]
# mis-transcription in `O0142`:

# %%
print(pp_data[target].data["dXS/dA"].entries["O0142"].measurements[0].y[:10])
pp_data[target].data["dXS/dA"].entries["O0142"].measurements[0].y[3] *= 0.1
pp_data[target].data["dXS/dA"].entries["O0142"].measurements[0].y_err[3] *= 0.1
pp_data[target].data["dXS/dA"].entries["O0142"].measurements[0].notes = [
    "12th to last pt decreased by factor of 10"
]

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        n_per_plot=4,
        label_kwargs={
            "label_xloc_deg": 45,
            "label_offset_factor": 1 / 2,
            "label_offset": True,
            "label_exfor": True,
        },
        plot_kwargs={
            "offsets": 1,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=10,
    )
)
axes[0].set_xlim([0, 120])
axes[-1].set_xlim([0, 90])

# %%
print(pp_data[target].data["dXS/dRuth"].entries["O0211"].measurements[0].y[-20:])
pp_data[target].data["dXS/dRuth"].entries["O0211"].measurements[0].y[-12] *= 0.1
pp_data[target].data["dXS/dRuth"].entries["O0211"].measurements[0].y_err[-12] *= 0.1
pp_data[target].data["dXS/dRuth"].entries["O0211"].measurements[0].notes = [
    "12th to last pt decreased by factor of 10"
]

# %% [markdown]
# ## $^{144}$Sm

# %%
target = Sm144
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 0}
# Number of (p,p) measurements: {'dXS/dA': 3, 'dXS/dRuth': 0}
# subentry C3000002 is missing statisitcal errors!
# Look at entry C3000 for (p,p) absolute
# subentry E0904044 is missing statisitcal errors!
# Look at entry E0904 for (p,p) absolute
# Look at entry O0032 for (p,p) absolute

# %%
# we handle O0032 below
del pp_data[target].data["dXS/dA"].entries['C3000']
del pp_target[target].data["dXS/dA"].entries['E0904']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 3
#       1 # we handle O0032 below
#       2 del pp_data[target].data["dXS/dA"].entries['C3000']
# ----> 3 del pp_target[target].data["dXS/dA"].entries['E0904']
#
# NameError: name 'pp_target' is not defined

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()
# Out:
# Entry: E0773
# E0773006  :  Error while parsing E0773006: Expected only one DATA column, found 2

# %% [markdown]
# `E0773` includes polarization data in the same subentry in an unclear way, we will skip it.

# %% [markdown]
# #### plotting

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        n_per_plot=2,
        label_kwargs={"label_exfor": True, "label_offset_factor": 0.005},
        plot_kwargs={"offsets": 100},
        y_size=4,
    )
)
axes[0].set_xlim([-5, 220])
# Out:
# (-5.0, 220.0)

# %%
pp_data[target].data["dXS/dA"].entries["E0904"].measurements[0].y_err = (
    pp_data[target].data["dXS/dA"].entries["O0032"].measurements[0].y_err
)
pp_data[target].data["dXS/dA"].entries["E0904"].measurements[0].statistical_err = (
    pp_data[target].data["dXS/dA"].entries["O0032"].measurements[0].statistical_err
)

del pp_data[target].data["dXS/dA"].entries["O0032"]
pp_data[target].data["dXS/dA"].entries["E0904"].measurements[0].notes = [
    "clearly the two 65 MeV data sets (published in PRC same author in ssubsequent years) is exactly the same with different normalizations. "
    "We will take the normalization from the later one, E0904. However, E0904 does not have errors, so we will take those from O0032."
]

# %% [markdown]
# ## $^{148}$Sm

# %%
target = Sm148
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 0}
# Number of (p,p) measurements: {'dXS/dA': 2, 'dXS/dRuth': 0}
# subentry C1397002 is missing statisitcal errors!
# subentry E0904046 is missing statisitcal errors!
# Look at entry E0904 for (p,p) absolute

# %%
del pp_data[target].data['dXS/dA'].entries['E0904']
del pp_data[target].data['dXS/dA'].entries['C1397']

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()
# Out:
# Entry: D0289
# D0289002  :  Ambiguous statistical error labels:
# ERR-DIG, DATA-ERR1, ERR-1, ERR-2, ERR-S
#
# ERR-ANALYS (ERR-1) Error in the determination of target thickness
#            (ERR-2) Error due to determination of solid angle and
#            calibration of the current integrator.
#            (ERR-S) Statistical error
# Entry: F1173
# F1173002  :  Ambiguous statistical error labels:
# ERR-DIG, DATA-ERR2
# ERR-ANALYS (DATA-ERR1,0.,6.) Cross section measurement error
#            (ANG-ERR-D)  Angle digitizing error
#            (ERR-DIG)    Data digitizing error
#            (DATA-ERR2)  Error from the graphic bars

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "D0289",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-S", "ERR-1", "ERR-2", "ERR-DIG"],
        "systematic_err_labels": ["DATA-ERR1"],
    },
)
# Out:
# Found subentry D0289002 with the following columns:
# ['EN', 'EN-RSL', 'ERR-DIG', 'DATA-ERR1', 'ERR-1', 'ERR-2', 'ANG-CM', 'DATA-CM', 'ERR-S']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "F1173",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR2", "ERR-DIG"],
    },
)
# Out:
# Found subentry F1173002 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM', 'DATA-ERR2']

# %% [markdown]
# #### plotting

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={"label_exfor": True, "label_offset_factor": 0.005},
        plot_kwargs={"offsets": 100},
        y_size=4,
    )
)

# %% [markdown]
# ## $^{116}$Sn

# %%
target = Sn116
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 3}
# Number of (p,p) measurements: {'dXS/dA': 2, 'dXS/dRuth': 3}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()
# Out:
# Entry: O0211
# O0211008  :  Ambiguous statistical error labels:
# DATA-ERR, ERR-T
#
# ERR-ANALYS (ERR-T).The Uncertainty is Reported by Authors.
#            (DATA-ERR).Data-Point Reader Uncertainty.
#            (ANG-ERR).Data-Point Reader Uncertainty.
# Entry: O0434
# O0434010  :  Error while parsing O0434010: Expected only one ERR-S column, found 2
#
# ERR-ANALYS (DATA-ERR).Data-Point Reader Uncertainty.
#            (ANG-ERR).Data-Point Reader Uncertainty.
#            (ERR-S).The Overall Uncertainty in the Absolute Cross
#            Sections was Estimated to be Less Than 5%.

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O0211",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR", "ERR-T"],
    },
)
# Out:
# Found subentry O0211008 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA', 'ERR-T']

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 160,
        },
        plot_kwargs={"offsets": 100},
        y_size=6,
    )
)
axes[0].set_xlim([-5, 210])
# Out:
# (-5.0, 210.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 150,
        },
        plot_kwargs={"offsets": 1000},
        y_size=4,
    )
)
axes[0].set_xlim([-5, 200])
# Out:
# (-5.0, 200.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=5,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{118}$Sn

# %%
target = Sn118
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 4}
# Number of (p,p) measurements: {'dXS/dA': 0, 'dXS/dRuth': 1}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 160,
        },
        plot_kwargs={"offsets": 100},
        y_size=8,
    )
)
axes[0].set_xlim([-5, 210])
# Out:
# (-5.0, 210.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=4,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{120}$Sn

# %%
target = Sn120
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 3}
# Number of (p,p) measurements: {'dXS/dA': 8, 'dXS/dRuth': 4}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()
# Out:
# Entry: 10633
# 10633017  :  Ambiguous statistical error labels:
# DATA-ERR2, MONIT-ERR, DATA-ERR1
# ERR-ANALYS (DATA-ERR1) Relative uncertainties
#            (DATA-ERR2) Normalization error

# %%
nn_data[target].data["dXS/dA"].reattempt_parse(
    "10633",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR1"],
        "systematic_err_labels": ["DATA-ERR2"],
    },
)
# Out:
# Found subentry 10633017 with the following columns:
# ['EN', 'DATA-ERR2', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ANG-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR1']

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()
# Out:
# Entry: O0302
# O0302006  :  Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR2, ERR-DIG
# ERR-ANALYS  The statistical error varied from 1 % at
#             small angles to 4 % at 50 degrees.
#            (DATA-ERR1) The overall error was calculated to
#             be +/- 5% for the relative cross sections and
#            (DATA-ERR2)  +/-7 % for the absolute cross sections.
#            (20201204A) SD: Data were re-digitized. ERR-ANALYS
#            deleted. STATUS updated.
# Entry: O0328
# O0328007  :  Ambiguous statistical error labels:
# ERR-2, ERR-3, ERR-DIG, ERR-1
# ERR-ANALYS (ERR-1) Statistical errors and the uncertainty
#             in background subtraction.
#            (ERR-2) Uncertainty in the current integration
#            (ERR-3) Uncertainty in determining the target thickness

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O0302",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR1", "ERR-DIG"],
        "systematic_err_labels": ["DATA-ERR2"],
    },
)
# Out:
# Found subentry O0302006 with the following columns:
# ['EN', 'DATA-ERR1', 'DATA-ERR2', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA']

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O0328",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-1", "ERR-DIG"],
        "systematic_err_labels": ["ERR-2", "ERR-3"],
    },
)
# Out:
# Found subentry O0328007 with the following columns:
# ['EN', 'EN-ERR', 'ERR-2', 'ERR-3', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA', 'ERR-1']

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()
# Out:
# Entry: O0049
# O0049010  :  Ambiguous statistical error labels:
# MONIT-ERR, ERR-T, ERR-DIG
# ERR-ANALYS (ERR-S,1.,6.) The statistical errors for the cross
#            sections were 1 to 2% for ang. < 25. degr. and 3 to 6%
#            for ang. > 25.degr.
#            (ERR-T) The overall uncertainty
#
# Entry: O0124
# O0124004  :  Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR2
# ERR-ANALYS (ANG-ERR).DATA-POINT READER UNCERTAINTY.
#            (EN-ERR).THE UNCERTAINTY IS REPORTED BY AUTHORS.
# ERR-ANALYS (DATA-ERR1).DATA-POINT READER UNCERTAINTY FROM FIG.1
#            (DATA-ERR2).DATA-POINT READER UNCERTAINTY FROM FIG.2.
# Entry: O0142
# O0142010  :  Ambiguous statistical error labels:
# ERR-1, ERR-T
# ERR-ANALYS ERRORS QUOTED AGAINST INDIVIDUAL MEASUREMENTS ARE
#            RELATIVE ERRORS WITHIN EACH ANGULAR DISTRIBUTION AND
#            WERE COMPOUNDED FROM THEC FOLLOWING CONTRIBUTIONS-
#            STATISTICAL ERROR ON THE NUMBER OF COUNTS IN THE
#            ELASTIC PEAK,ERROR IN COUNTING LOSS CORRECTIONS,ERROR
#            IN CORRECTION FOR SCATTERING BY IMPURITIES,DUE MAINLY
#            TO UNCERTAINTY IN THE AMOUNT OF CONTAMINATION,RESIDUAL
#            UNCERTAINTY IN SCATTERING ANGLE AFTER CORRECTIONS HAD
#            BEEN MADE.THIS WAS TRANSFORMED TO AN ERROR IN CROSS
#            SECTION AT THE NOMINAL SCATTERING ANGLE.
#            (ERR-T).THE UNCERTAINTY IS REPORTED BY AUTHORS.
#            (ERR-1). THE UNCERTAINTY OF THE NORMALIZATION. THIS
#            ARISES ALMOST ENTIRELY FROM INACCURACYIN
#            DETERMINATIONOF THE SUPERFICIAL OF TARGET.

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0049",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-DIG", "ERR-T"],
        "systematic_err_labels": ["MONIT-ERR"],
    },
)
# Out:
# Found subentry O0049010 with the following columns:
# ['EN', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ERR-T', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0124",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR1"],
        "systematic_err_labels": [],
    },
)
# Out:
# Found subentry O0124004 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'DATA-ERR1', 'DATA-ERR2', 'ANG-CM', 'DATA', 'FLAG']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0142",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-T"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry O0142010 with the following columns:
# ['EN', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-T']

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_xloc_deg": 160,
            "label_offset_factor": 0.02,
            "label_energy_err": False,
            "label_offset": False,
            "label_incident_energy": True,
            "label_excitation_energy": False,
            "label_exfor": True,
        },
        plot_kwargs={"offsets": 100},
        y_size=6,
    )
)
axes[0].set_xlim([-5, 210])
# Out:
# (-5.0, 210.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        n_per_plot=6,
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.1,
            "label_xloc_deg": 70.0,
        },
        plot_kwargs={"offsets": 1000},
        y_size=8,
    )
)
axes[0].set_xlim([0, 180])
axes[1].set_xlim([0, 90])
# Out:
# (0.0, 90.0)

# %%
print(pp_data[target].data["dXS/dA"].entries["C2174"].measurements[0].y[:12])
pp_data[target].data["dXS/dA"].entries["C2174"].measurements[0].y[8] *= 10
pp_data[target].data["dXS/dA"].entries["C2174"].measurements[0].notes = [
    "8th pt increased by factor of 10"
]
# Out:
# [2.2086e+01 6.8410e+00 2.9160e+00 1.1890e+00 4.3300e-01 1.6170e-01
#  9.4200e-02 7.9400e-02 1.0800e-02 5.8500e-02 4.0900e-02 2.3800e-02]

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_xloc_deg": 120,
            "label_offset_factor": 1 / 2,
            "label_energy_err": False,
            "label_offset": False,
            "label_incident_energy": True,
            "label_excitation_energy": False,
            "label_exfor": True,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=5,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{122}$Sn

# %%
target = Sn122
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
# Out:
# Number of (n,n) measurements: {'dXS/dA': 1}
# Number of (p,p) measurements: {'dXS/dA': 0, 'dXS/dRuth': 2}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.1,
            "label_xloc_deg": 120,
        },
        plot_kwargs={"offsets": 100},
        y_size=4,
    )
)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 1,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=5,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{124}$Sn

# %%
target = Sn124
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
# Out:
# Number of (n,n) measurements: {'dXS/dA': 2}
# Number of (p,p) measurements: {'dXS/dA': 1, 'dXS/dRuth': 2}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 160,
        },
        plot_kwargs={"offsets": 100},
        y_size=4,
    )
)
axes[0].set_xlim([-5, 210])
# Out:
# (-5.0, 210.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 150,
        },
        plot_kwargs={"offsets": 1000},
        y_size=4,
    )
)
axes[0].set_xlim([-5, 200])
# Out:
# (-5.0, 200.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 1,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=4,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{90}$Zr

# %%
target = Zr90
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
# Out:
# Number of (n,n) measurements: {'dXS/dA': 3}
# Number of (p,p) measurements: {'dXS/dA': 8, 'dXS/dRuth': 4}

# %%
del pp_data[Zr90].data["dXS/dA"].entries["O0032"]  # duplicate to E0166

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()
# Out:
# Entry: O0211
# O0211007  :  Ambiguous statistical error labels:
# DATA-ERR, ERR-T
#
# ERR-ANALYS (ERR-T).The Uncertainty is Reported by Authors.
#            (DATA-ERR).Data-Point Reader Uncertainty.
#            (ANG-ERR).Data-Point Reader Uncertainty.
# Entry: O0389
# O0389002  :  Ambiguous statistical error labels:
# ERR-1
# ERR-ANALYS (ERR-1) Normalization uncertainty includes:
#             * uncertainty of measured target thickness,
#             * uncertainty of the detector solid-angle measurement,
#             * uncertainty of the beam integration measurements
#            (ERR-2) Errors affecting primarily the shapes of the
#            angular distributions:
#             * For elastic scattering the errors due to counting
#            statistics were very small, and the estimate of error
#            was obtained from the reproducibility of the data
#            points.
#             * For inelastic scattering the major contributions to
#            error include counting statistics and the estimation of
#            the error associated with subtraction of the background
#            due to the low-energy tail of the elastically scattered
#            protons and due to alpha particles from (p,alpha)
#            reactions.
#            ERR-ANALYS deleted (see Subent 001).
# Entry: O1825
# O1825003  :  Ambiguous statistical error labels:
# ERR-1, ERR-DIG
# ERR-ANALYS (ANG-ERR-D).Digitizing error of angle.
#            (ERR-1).The resulting uncertainty in the absolute
#            normalization of the analyzing power data and the cross
#            section arising from beam integration and target
#            thickness measurements amounted to about +- 10%, not
#            taken into account in error bars.
#            Relative normalization of cross sections
#            could be achieved with an accuracy better than 5%.
# ERR-ANALYS (ERR-DIG).Digitizing error of  data.

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O0211",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR", "ERR-T"],
    },
)
# Out:
# Found subentry O0211007 with the following columns:
# ['EN', 'EN-RSL', 'ANG-ERR', 'DATA-ERR', 'ANG-CM', 'DATA', 'ERR-T']

# %%
pp_data[target].data["dXS/dRuth"].reattempt_parse(
    "O1825",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-DIG"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry O1825003 with the following columns:
# ['EN', 'ANG-ERR-D', 'ERR-1', 'ERR-DIG', 'ANG-CM', 'DATA']

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()
# Out:
# Entry: O0049
# O0049009  :  Ambiguous statistical error labels:
# MONIT-ERR, ERR-T, ERR-DIG
# ERR-ANALYS (ERR-S,1.,6.) The statistical errors for the cross
#            sections were 1 to 2% for ang. < 25. degr. and 3 to 6%
#            for ang. > 25.degr.
#            (ERR-T) The overall uncertainty
#
# Entry: O0208
# O0208008  :  Ambiguous statistical error labels:
# ERR-1, ERR-2
# ERR-ANALYS (ERR-1) Uncertainty in the target thickness.
# ERR-ANALYS (ERR-2) Relative error include all sources of error
#            except uncertainty in the target thickness.
# Entry: O0389
# O0389002  :  Ambiguous statistical error labels:
# ERR-1, ERR-2
# ERR-ANALYS (ERR-1) Normalization uncertainty includes:
#             * uncertainty of measured target thickness,
#             * uncertainty of the detector solid-angle measurement,
#             * uncertainty of the beam integration measurements
#            (ERR-2) Errors affecting primarily the shapes of the
#            angular distributions:
#             * For elastic scattering the errors due to counting
#            statistics were very small, and the estimate of error
#            was obtained from the reproducibility of the data
#            points.
#             * For inelastic scattering the major contributions to
#            error include counting statistics and the estimation of
#            the error associated with subtraction of the background
#            due to the low-energy tail of the elastically scattered
#            protons and due to alpha particles from (p,alpha)
#            reactions.
#            ERR-ANALYS deleted (see Subent 001).
# Entry: T0101
# T0101003  :  Ambiguous statistical error labels:
# DATA-ERR1, DATA-ERR
# ERR-ANALYS (DATA-ERR) Total systematic error, arising from
#             uncertainties in target thickness, charge integration,
#             target angle and spectrograph solid angle estimated
#             to be about 8-10%.
#            Relative errors from all sources were combined in
#             quadrature to obtain total relative uncertainty
#             which was typically 2-3% at angles less than 60
#             degrees. Relative uncertainty arose mainly from
#             following sources:
#             . Statistical errors (typically 1-2%, and rarely
#               larger than 10%),
#             . Deadtime uncertainty (kept below 1%),
#             . Uncertainty in charge collection (up to 1 %
#               at forward angles),
#             . uncertainties in the effective scattering angle and
#               uncertainty in the zero-degree angle (<7%).
#             . additional contribution from unknown sources (1%).
#            Angle error estimated to be 0.03 degrees.

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0049",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-DIG", "ERR-T"],
        "systematic_err_labels": ["MONIT-ERR"],
    },
)
# Out:
# Found subentry O0049009 with the following columns:
# ['EN', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ERR-T', 'ANG-ERR-D', 'ERR-DIG', 'ANG-CM', 'DATA-CM']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0208",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-2"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry O0208008 with the following columns:
# ['EN', 'ERR-1', 'ANG-ERR', 'ANG-CM', 'DATA-CM', 'ERR-2']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0389",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-2"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry O0389002 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-2']

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "T0101",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR"],
        "systematic_err_labels": ["DATA-ERR1"],
    },
)
# Out:
# Found subentry T0101003 with the following columns:
# ['DATA-ERR1', 'EN', 'ANG-CM', 'DATA', 'DATA-ERR']

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 160,
        },
        plot_kwargs={"offsets": 100},
        y_size=8,
    )
)
axes[0].set_xlim([-5, 210])
# Out:
# (-5.0, 210.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        n_per_plot=7,
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.0004,
            "label_xloc_deg": 140,
        },
        plot_kwargs={"offsets": 100},
    )
)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=9,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{92}$Zr

# %%
target = Zr92
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
# Out:
# Number of (n,n) measurements: {'dXS/dA': 2}
# Number of (p,p) measurements: {'dXS/dA': 5, 'dXS/dRuth': 2}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()
# Out:
# Entry: O0389
# O0389022  :  Ambiguous statistical error labels:
# ERR-1
# ERR-ANALYS (ERR-1) Normalization uncertainty includes:
#             * uncertainty of measured target thickness,
#             * uncertainty of the detector solid-angle measurement,
#             * uncertainty of the beam integration measurements
#            (ERR-2) Errors affecting primarily the shapes of the
#            angular distributions:
#             * For elastic scattering the errors due to counting
#            statistics were very small, and the estimate of error
#            was obtained from the reproducibility of the data
#            points.
#             * For inelastic scattering the major contributions to
#            error include counting statistics and the estimation of
#            the error associated with subtraction of the background
#            due to the low-energy tail of the elastically scattered
#            protons and due to alpha particles from (p,alpha)
#            reactions.
#            ERR-ANALYS deleted (see Subent 001).

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()
# Out:
# Entry: O0389
# O0389022  :  Ambiguous statistical error labels:
# ERR-1, ERR-2
# ERR-ANALYS (ERR-1) Normalization uncertainty includes:
#             * uncertainty of measured target thickness,
#             * uncertainty of the detector solid-angle measurement,
#             * uncertainty of the beam integration measurements
#            (ERR-2) Errors affecting primarily the shapes of the
#            angular distributions:
#             * For elastic scattering the errors due to counting
#            statistics were very small, and the estimate of error
#            was obtained from the reproducibility of the data
#            points.
#             * For inelastic scattering the major contributions to
#            error include counting statistics and the estimation of
#            the error associated with subtraction of the background
#            due to the low-energy tail of the elastically scattered
#            protons and due to alpha particles from (p,alpha)
#            reactions.
#            ERR-ANALYS deleted (see Subent 001).

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0389",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-2"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry O0389022 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-2']

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 160,
        },
        plot_kwargs={"offsets": 100},
        y_size=6,
    )
)
axes[0].set_xlim([-5, 210])
# Out:
# (-5.0, 210.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 150,
        },
        plot_kwargs={"offsets": 1000},
    )
)
axes[0].set_xlim([-5, 200])
# Out:
# (-5.0, 200.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=4,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{94}$Zr

# %%
target = Zr94
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
# Out:
# Number of (n,n) measurements: {'dXS/dA': 2}
# Number of (p,p) measurements: {'dXS/dA': 1, 'dXS/dRuth': 2}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()
# Out:
# Entry: O0389
# O0389033  :  Ambiguous statistical error labels:
# ERR-1
# ERR-ANALYS (ERR-1) Normalization uncertainty includes:
#             * uncertainty of measured target thickness,
#             * uncertainty of the detector solid-angle measurement,
#             * uncertainty of the beam integration measurements
#            (ERR-2) Errors affecting primarily the shapes of the
#            angular distributions:
#             * For elastic scattering the errors due to counting
#            statistics were very small, and the estimate of error
#            was obtained from the reproducibility of the data
#            points.
#             * For inelastic scattering the major contributions to
#            error include counting statistics and the estimation of
#            the error associated with subtraction of the background
#            due to the low-energy tail of the elastically scattered
#            protons and due to alpha particles from (p,alpha)
#            reactions.
#            ERR-ANALYS deleted (see Subent 001).

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()
# Out:
# Entry: O0389
# O0389033  :  Ambiguous statistical error labels:
# ERR-1, ERR-2
# ERR-ANALYS (ERR-1) Normalization uncertainty includes:
#             * uncertainty of measured target thickness,
#             * uncertainty of the detector solid-angle measurement,
#             * uncertainty of the beam integration measurements
#            (ERR-2) Errors affecting primarily the shapes of the
#            angular distributions:
#             * For elastic scattering the errors due to counting
#            statistics were very small, and the estimate of error
#            was obtained from the reproducibility of the data
#            points.
#             * For inelastic scattering the major contributions to
#            error include counting statistics and the estimation of
#            the error associated with subtraction of the background
#            due to the low-energy tail of the elastically scattered
#            protons and due to alpha particles from (p,alpha)
#            reactions.
#            ERR-ANALYS deleted (see Subent 001).

# %%
pp_data[target].data["dXS/dA"].reattempt_parse(
    "O0389",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-2"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry O0389033 with the following columns:
# ['EN', 'EN-ERR', 'ANG-ERR', 'ERR-1', 'ANG-CM', 'DATA-CM', 'ERR-2']

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 160,
        },
        plot_kwargs={"offsets": 100},
        y_size=8,
    )
)
axes[0].set_xlim([-5, 210])
# Out:
# (-5.0, 210.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 150,
        },
        plot_kwargs={"offsets": 1000},
    )
)
axes[0].set_xlim([-5, 200])
# Out:
# (-5.0, 200.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=5,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{96}$Zr

# %%
target = Zr96
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
# Out:
# Number of (n,n) measurements: {'dXS/dA': 0}
# Number of (p,p) measurements: {'dXS/dA': 1, 'dXS/dRuth': 1}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()

# %% [markdown]
# #### plotting

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 150,
        },
        plot_kwargs={"offsets": 1000},
        y_size=4,
    )
)
axes[0].set_xlim([-5, 200])
# Out:
# (-5.0, 200.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=4,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{64}$Ni

# %%
target = Ni64
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
flag_entries(target)
# Out:
# Number of (n,n) measurements: {'dXS/dA': 0}
# Number of (p,p) measurements: {'dXS/dA': 5, 'dXS/dRuth': 4}
# Look at entry E0249 for (p,p) absolute
# Look at entry O0032 for (p,p) absolute
# subentry O0432003 is missing statisitcal errors!
# Look at entry O0432 for (p,p) ratio

# %%
del pp_data[target].data["dXS/dA"].entries["E0249"]
del pp_data[target].data["dXS/dA"].entries["O0032"]
del pp_data[target].data["dXS/dRuth"].entries["O0432"]

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()

# %% [markdown]
# #### plotting

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 150,
        },
        plot_kwargs={"offsets": 1000},
        y_size=4,
    )
)
axes[0].set_xlim([-5, 200])
# Out:
# (-5.0, 200.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=4,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{86}$Sr

# %%
target = Sr86
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
# Out:
# Number of (n,n) measurements: {'dXS/dA': 0}
# Number of (p,p) measurements: {'dXS/dA': 0, 'dXS/dRuth': 1}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()

# %% [markdown]
# #### plotting

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=4,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{88}$Sr

# %%
target = Sr88
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
# Out:
# Number of (n,n) measurements: {'dXS/dA': 1}
# Number of (p,p) measurements: {'dXS/dA': 0, 'dXS/dRuth': 1}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 160,
        },
        plot_kwargs={"offsets": 100},
        y_size=4,
    )
)
axes[0].set_xlim([-5, 210])
# Out:
# (-5.0, 210.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=4,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{92}$Mo

# %%
target = Mo92
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
# Out:
# Number of (n,n) measurements: {'dXS/dA': 1}
# Number of (p,p) measurements: {'dXS/dA': 9, 'dXS/dRuth': 2}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()
# Out:
# Entry: 10633
# 10633012  :  Ambiguous statistical error labels:
# DATA-ERR2, MONIT-ERR, DATA-ERR1
# ERR-ANALYS (DATA-ERR1) Relative uncertainties
#            (DATA-ERR2) Normalization error
#
# Entry: 10867
# 10867002  :  Ambiguous statistical error labels:
# ERR-1, ERR-T
# ERR-ANALYS (ERR-T) Overall uncertainty generally less than 10%
#             but as high as 20% for some backward angles.
#            (ERR-1) Normalization error approx 5%
#            (ANG-ERR) Scattering angle error approx 0.3 degrees

# %%
nn_data[target].data["dXS/dA"].reattempt_parse(
    "10633",
    parsing_kwargs={
        "statistical_err_labels": ["DATA-ERR1"],
        "systematic_err_labels": ["DATA-ERR2"],
    },
)
# Out:
# Found subentry 10633012 with the following columns:
# ['EN', 'DATA-ERR2', 'ANG-NRM', 'MONIT', 'MONIT-ERR', 'ANG-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR1']

# %%
nn_data[target].data["dXS/dA"].reattempt_parse(
    "10867",
    parsing_kwargs={
        "statistical_err_labels": ["ERR-T"],
        "systematic_err_labels": ["ERR-1"],
    },
)
# Out:
# Found subentry 10867002 with the following columns:
# ['ANG-ERR', 'ERR-1', 'EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'ERR-T']

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()

# %% [markdown]
# #### plotting

# %%
axes = (
    nn_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 160,
        },
        plot_kwargs={"offsets": 100},
        y_size=6,
    )
)
axes[0].set_xlim([-5, 210])
# Out:
# (-5.0, 210.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        n_per_plot=6,
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.001,
            "label_xloc_deg": 160,
        },
        plot_kwargs={"offsets": 100},
    )
)
axes[0].set_xlim([0, 200])
axes[1].set_xlim([0, 200])
# Out:
# (0.0, 200.0)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 2,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=4,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## $^{94}$Mo

# %%
target = Mo94
print(f"Number of (n,n) measurements: {nn_data[target].num_measurements}")
print(f"Number of (p,p) measurements: {pp_data[target].num_measurements}")
# Out:
# Number of (n,n) measurements: {'dXS/dA': 0}
# Number of (p,p) measurements: {'dXS/dA': 2, 'dXS/dRuth': 3}

# %% [markdown]
# #### failed parses

# %%
nn_data[target].data["dXS/dA"].print_failed_parses()

# %%
pp_data[target].data["dXS/dRuth"].print_failed_parses()

# %%
pp_data[target].data["dXS/dA"].print_failed_parses()

# %% [markdown]
# #### plotting

# %%
axes = (
    pp_data[target]
    .data["dXS/dA"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 0.01,
            "label_xloc_deg": 60,
        },
        plot_kwargs={"offsets": 100},
        y_size=6,
    )
)

# %%
axes = (
    pp_data[target]
    .data["dXS/dRuth"]
    .plot(
        label_kwargs={
            "label_exfor": True,
            "label_offset_factor": 1 / 2,
            "label_xloc_deg": 150,
        },
        plot_kwargs={
            "offsets": 1,
            "log": False,
            "draw_baseline": True,
            "baseline_offset": 1,
        },
        y_size=6,
    )
)
axes[0].set_xlim([-20, 200])
# Out:
# (-20.0, 200.0)

# %% [markdown]
# ## Now let's take a look at some attributes of the data

# %% [markdown]
# Now that we've removed outliers and fixed failed parses, we should re-cross-reference by entry and re-count the total number of data points:

# %%
for quantity, data in pp_data.items():
    data.post_process_entries()
for quantity, data in nn_data.items():
    data.post_process_entries()
# Out:
# (40,20): found duplicates between (p,p) absolute and ratio to Rutherford in O0211
# [np.float64(61.4)]
# [np.float64(61.4)]
# (90,40): found duplicates between (p,p) absolute and ratio to Rutherford in O0211
# [np.float64(61.4)]
# [np.float64(61.4)]
# (116,50): found duplicates between (p,p) absolute and ratio to Rutherford in O0211
# [np.float64(61.4)]
# [np.float64(61.4)]
# (208,82): found duplicates between (p,p) absolute and ratio to Rutherford in O0211
# [np.float64(61.4)]
# [np.float64(61.4)]

# %% [markdown]
# We can see how many data points and measurements we have:

# %%
for target, data in pp_data.items():
    print(target, data.num_data_pts, data.num_measurements)
# Out:
# (48, 20) {'dXS/dA': 385, 'dXS/dRuth': 82} {'dXS/dA': 9, 'dXS/dRuth': 3}
# (40, 20) {'dXS/dA': 1148, 'dXS/dRuth': 812} {'dXS/dA': 28, 'dXS/dRuth': 22}
# (64, 28) {'dXS/dA': 87, 'dXS/dRuth': 130} {'dXS/dA': 3, 'dXS/dRuth': 3}
# (86, 38) {'dXS/dA': 0, 'dXS/dRuth': 29} {'dXS/dA': 0, 'dXS/dRuth': 1}
# (88, 38) {'dXS/dA': 0, 'dXS/dRuth': 29} {'dXS/dA': 0, 'dXS/dRuth': 1}
# (90, 40) {'dXS/dA': 464, 'dXS/dRuth': 193} {'dXS/dA': 12, 'dXS/dRuth': 6}
# (92, 40) {'dXS/dA': 131, 'dXS/dRuth': 66} {'dXS/dA': 6, 'dXS/dRuth': 2}
# (94, 40) {'dXS/dA': 75, 'dXS/dRuth': 64} {'dXS/dA': 2, 'dXS/dRuth': 2}
# (96, 40) {'dXS/dA': 34, 'dXS/dRuth': 37} {'dXS/dA': 1, 'dXS/dRuth': 1}
# (92, 42) {'dXS/dA': 278, 'dXS/dRuth': 55} {'dXS/dA': 9, 'dXS/dRuth': 2}
# (94, 42) {'dXS/dA': 64, 'dXS/dRuth': 97} {'dXS/dA': 2, 'dXS/dRuth': 3}
# (116, 50) {'dXS/dA': 30, 'dXS/dRuth': 158} {'dXS/dA': 1, 'dXS/dRuth': 4}
# (118, 50) {'dXS/dA': 0, 'dXS/dRuth': 27} {'dXS/dA': 0, 'dXS/dRuth': 1}
# (120, 50) {'dXS/dA': 324, 'dXS/dRuth': 201} {'dXS/dA': 11, 'dXS/dRuth': 6}
# (122, 50) {'dXS/dA': 0, 'dXS/dRuth': 60} {'dXS/dA': 0, 'dXS/dRuth': 2}
# (124, 50) {'dXS/dA': 30, 'dXS/dRuth': 60} {'dXS/dA': 1, 'dXS/dRuth': 2}
# (138, 56) {'dXS/dA': 30, 'dXS/dRuth': 22} {'dXS/dA': 1, 'dXS/dRuth': 1}
# (140, 58) {'dXS/dA': 23, 'dXS/dRuth': 0} {'dXS/dA': 2, 'dXS/dRuth': 0}
# (144, 62) {'dXS/dA': 49, 'dXS/dRuth': 0} {'dXS/dA': 1, 'dXS/dRuth': 0}
# (148, 62) {'dXS/dA': 50, 'dXS/dRuth': 0} {'dXS/dA': 2, 'dXS/dRuth': 0}
# (206, 82) {'dXS/dA': 0, 'dXS/dRuth': 32} {'dXS/dA': 0, 'dXS/dRuth': 1}
# (208, 82) {'dXS/dA': 917, 'dXS/dRuth': 253} {'dXS/dA': 15, 'dXS/dRuth': 7}

# %%
for target, data in nn_data.items():
    print(target, data.num_data_pts, data.num_measurements)
# Out:
# (48, 20) {'dXS/dA': 45} {'dXS/dA': 2}
# (40, 20) {'dXS/dA': 178} {'dXS/dA': 14}
# (64, 28) {'dXS/dA': 0} {'dXS/dA': 0}
# (86, 38) {'dXS/dA': 0} {'dXS/dA': 0}
# (88, 38) {'dXS/dA': 28} {'dXS/dA': 1}
# (90, 40) {'dXS/dA': 96} {'dXS/dA': 3}
# (92, 40) {'dXS/dA': 70} {'dXS/dA': 2}
# (94, 40) {'dXS/dA': 68} {'dXS/dA': 2}
# (96, 40) {'dXS/dA': 0} {'dXS/dA': 0}
# (92, 42) {'dXS/dA': 129} {'dXS/dA': 5}
# (94, 42) {'dXS/dA': 0} {'dXS/dA': 0}
# (116, 50) {'dXS/dA': 89} {'dXS/dA': 3}
# (118, 50) {'dXS/dA': 98} {'dXS/dA': 4}
# (120, 50) {'dXS/dA': 114} {'dXS/dA': 4}
# (122, 50) {'dXS/dA': 28} {'dXS/dA': 1}
# (124, 50) {'dXS/dA': 53} {'dXS/dA': 2}
# (138, 56) {'dXS/dA': 0} {'dXS/dA': 0}
# (140, 58) {'dXS/dA': 0} {'dXS/dA': 0}
# (144, 62) {'dXS/dA': 0} {'dXS/dA': 0}
# (148, 62) {'dXS/dA': 0} {'dXS/dA': 0}
# (206, 82) {'dXS/dA': 75} {'dXS/dA': 2}
# (208, 82) {'dXS/dA': 331} {'dXS/dA': 16}

# %%
num_nn_measuremenmts = int(
    np.sum([np.sum(list(d.num_measurements.values())) for d in nn_data.values()])
)
num_pp_measuremenmts = int(
    np.sum([np.sum(list(d.num_measurements.values())) for d in pp_data.values()])
)
num_nn_pts = int(
    np.sum([np.sum(list(d.num_data_pts.values())) for d in nn_data.values()])
)
num_pp_pts = int(
    np.sum([np.sum(list(d.num_data_pts.values())) for d in pp_data.values()])
)
print(
    f"There are {num_nn_pts} data points in {num_nn_measuremenmts} differential cross sections for (n,n)"
)
print(
    f"There are {num_pp_pts} data points in {num_pp_measuremenmts} differential cross sections for (p,p)"
)
# Out:
# There are 1402 data points in 61 differential cross sections for (n,n)
# There are 6526 data points in 176 differential cross sections for (p,p)

# %% [markdown]
# By cross-referencing by entry, we can see what the common systematic errors are for single experiments with multiple isotopes, energies, quantities, etc., which can be very useful in evaluation, calibration and UQ.

# %% [markdown]
# If we were to construct a likelihood function for calibrating to this data, we would have to consider the correlations in normalization between data sets from the same entry,(making the assumption that each subentry within an entry shares the same systematic error in the normalization):

# %%
all_data = list(pp_data.values()) + list(nn_data.values())
all_data_by_entry, sys_uncertainties_by_entry = (
    curate.cross_reference_entry_systematic_err(all_data)
)

# %%
print(f"{len(all_data_by_entry.keys())} different Exfor entries!")
# Out:
# 76 different Exfor entries!

# %% [markdown]
# Let's do some consistency checks:

# %%
# check if any entries are on the ignore list
for entry_id, data in all_data_by_entry.items():
    for entry in data:
        if (
            entry_id in entries_to_ignore_nn
            and entry.quantity == "dXS/dA"
            and entry.reaction.projectile == neutron
        ):
            print(entry.reaction.pretty_string, entry.quantity, entry_id, "(n,n)")
        if (
            entry_id in entries_to_ignore_pp_Ruth
            and entry.quantity == "dXS/dRuth"
            and entry.reaction.projectile == proton
        ):
            print(entry.reaction.pretty_string, entry.quantity, entry_id, "(p,p) ratio")
        if (
            entry_id in entries_to_ignore_pp_absolute
            and entry.quantity == "dXS/dA"
            and entry.reaction.projectile == proton
        ):
            print(entry.reaction.pretty_string, entry_id, "(p,p)")
# Out:
# $^{144}$Sm$(p,p)$ E0904 (p,p)

# %% [markdown]
# Let's make sure all the data has statistical uncertainties reported:

# %%
# go through entry by entry and check errors:
entries_missing_stat_errs = {}
for entry_id, data in all_data_by_entry.items():
    for entry in data:
        for m in entry.measurements:
            if np.allclose(m.statistical_err, 0.0):
                if entry not in entries_missing_stat_errs:
                    entries_missing_stat_errs[entry_id] = [m.subentry]
                else:
                    entries_missing_stat_errs[entry_id].append(m.subentry)

# if an entry has subentries missing statistical errors, report it
for entry_id, flagged_subentries in entries_missing_stat_errs.items():
    subentries = []
    reactions = []
    for entry in all_data_by_entry[entry_id]:
        reactions.append(f"{entry.reaction.pretty_string} {entry.quantity}")
        for m in entry.measurements:
            subentries.append(m.subentry)
    print(
        f"Entry: {entry_id}: reaction: "
        + ", ".join(reactions)
        + "\n\tsubentries: "
        + ", ".join(subentries)
        + "\n\t flagged  : "
        + ", ".join(flagged_subentries)
        #  + f"\n\t{entry.meta}"
    )
print(f"Total flagged entries: {len(entries_missing_stat_errs)}")
# Out:
# Total flagged entries: 0

# %% [markdown]
# At this point, we can just remove these entries, or assign them some estimate for statistical uncertainty

# %%
# make sure statistical err is reported, if not assign it a default
# separate systematic err in subentry for systematic err across entire entry
# if a subentry does not have systematic error assigned, assign it a default

# %% [markdown]
# We can write our data to disk like so:

# %%
import pickle

with open("pp_elastic_data.pkl", "wb") as f:
    pickle.dump(pp_data, f)
with open("nn_elastic_data.pkl", "wb") as f:
    pickle.dump(pp_data, f)
